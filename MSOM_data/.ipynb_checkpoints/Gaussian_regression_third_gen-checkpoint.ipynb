# %%
import numpy as np
import pandas as pd
import scipy
import time
import sys
sys.path.append('../sourcing_models/')
import matplotlib.pyplot as plt
from lib.dual_sourcing import *

import sys
sys.path.append('../')
import torch
from neural_control.controllers import DualFullyConnectedRegressionController, imitatation_learn
from neural_control.dynamics import DualSourcingModel
from copy import deepcopy
from sourcing_models.utilities import sample_trajectories_capped_dual_index, \
sample_trajectories_dual_index, sample_trajectories_single_index, sample_trajectories_tailored_base_surge

from collections import Counter
from scipy.stats import truncnorm
from matplotlib import rcParams
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)

# customized settings
params = {  # 'backend': 'ps',
    'font.family': 'serif',
    'font.serif': 'Fira',
    'font.size': 10,
    'axes.labelsize': 'medium',
    'axes.titlesize': 'medium',
    'legend.fontsize': 'medium',
    'xtick.labelsize': 'small',
    'ytick.labelsize': 'small',
    'savefig.dpi': 150,
    'text.usetex': True}
# tell matplotlib about your params
rcParams.update(params)

# set nice figure sizes
fig_width_pt = 245    # Get this from LaTeX using \showthe\columnwidth
golden_mean = (np.sqrt(5.) - 1.) / 2.  # Aesthetic ratio
ratio = golden_mean
inches_per_pt = 1. / 72.27  # Convert pt to inches
fig_width = fig_width_pt * inches_per_pt  # width in inches
fig_height = fig_width*ratio  # height in inches
fig_size = [fig_width, fig_height]
rcParams.update({'figure.figsize': fig_size})

# %% [markdown]
# # Load data
# We first load the data that was published along with the MSOM article "Data Set: 187 Weeks of Customer Forecasts and Orders for Microprocessors from Intel Corporation".

# %%
data = pd.read_csv("msom.2020.0933.csv")
max_weeks = max(data["Week"].to_numpy())
max_weeks = 115
X = np.arange(1,max_weeks+1)

# %% [markdown]
# Next, we select the relevant stock keeping units (SKUs) and customer orders.

# %%
def select_SKUs(SKUs):
    
    y = []
    for SKU in SKUs:
        
        data_ = data[data["SKU"] == SKU]
        weeks = data_[data_["SKU"] == SKU]["Week"].to_numpy()
        orders = data_[data_["SKU"] == SKU]["Customer Orders"].to_numpy()
        data_["Total Customer Orders"] = data_.groupby(["Week"])['Customer Orders'].transform('sum')
        total_orders = data_["Total Customer Orders"].to_numpy()
        
        weeks_total_orders = sorted(set([(x[0],x[1]) for x in zip(weeks,total_orders)]))
        
        weeks_ = np.array([x[0] for x in weeks_total_orders])
        total_orders_ = np.array([x[1] for x in weeks_total_orders])
        
        y_ = []
        for i in range(len(X)):
            
            if X[i] in weeks_:
                y_.append(total_orders_[X[i] == weeks_][0])
            else:
                y_.append(np.nan)
        
        y.append(np.array(y_))
    
    return np.array(y)

# %% [markdown]
# We select third generation SKUs.

# %%
#SKUs = ["SKU-A-2", "SKU-B-2", "SKU-C-1", "SKU-C-2", "SKU-F-1", "SKU-F-2", "SKU-H-2", "SKU-I-2", "SKU-J-2", "SKU-K-2", "SKU-L-1", "SKU-L-2", "SKU-M-2", "SKU-O-1", "SKU-O-2", "SKU-Q-2", "SKU-S-2"]
SKUs = ["SKU-A-3", "SKU-B-3", "SKU-C-3", "SKU-E-3", "SKU-H-3", "SKU-I-3", "SKU-J-3", "SKU-N-3", "SKU-S-3", "SKU-T-3"]
y = select_SKUs(SKUs)
# Out:
# /home/lucasb/anaconda3/envs/inventory/lib/python3.6/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
y_impute = np.nan_to_num(y,nan=0)
max_y = np.max(y_impute)

# %% [markdown]
# # Model data by Gaussian process

# %% [markdown]
# We now determine the means and standard deviations separately for all weeks.

# %%
mean_arr = np.array([np.mean(y_impute[:,i]/1e5) for i in range(len(X))])
std_arr = np.array([np.std(y_impute[:,i]/1e5,ddof=1) for i in range(len(X))])

# %% [markdown]
# Plot the original data, mean, and 95% confidence interval.

# %%
fig, ax = plt.subplots(facecolor='white')
for i in range(len(SKUs)):
    plt.plot(X, y_impute[i]/1e5,alpha=0.3,color='Grey')
plt.plot(X,mean_arr,color='tab:blue',alpha=0.8)
plt.fill_between(X,mean_arr+1.96*std_arr,mean_arr-1.96*std_arr,alpha=0.3)
ax.xaxis.set_minor_locator(MultipleLocator(5))
plt.xlim(0,120)
plt.ylim(0,2.5)
plt.xlabel(r"week")
plt.ylabel(r"customer orders [$\times 10^5$]")
plt.tight_layout()
plt.savefig("gaussian_sampling.png",dpi=480)
plt.show()

# %% [markdown]
# Generate samples using a truncated normal distribution.

# %%
num_samples = 1000
samples = []
myclip_a = 0
myclip_b = 1e3

for i in range(len(mean_arr)):
    
    my_mean = mean_arr[i]
    my_std = std_arr[i]
    a, b = (myclip_a - my_mean) / (1e-9+my_std), (myclip_b - my_mean) / (1e-9+my_std)
    r = truncnorm.rvs(a, b, loc=my_mean, scale=my_std, size=num_samples)
    samples.append(r)

# %%
x = np.linspace(0,4,100)
plt.figure()
for i in range(40):
    myclip_a = 0
    myclip_b = 1e2
    my_mean = mean_arr[i]
    my_std = std_arr[i]
    a, b = (myclip_a - my_mean) / (1e-9+my_std), (myclip_b - my_mean) / (1e-9+my_std)
    rv = truncnorm(a, b, loc=my_mean, scale=my_std)
    r = lambda x: rv.pdf(x)
    plt.plot(x,r(x))
plt.xlabel(r"orders")
plt.ylabel(r"PDF")
plt.show()
# Out:
# /home/lucasb/anaconda3/envs/inventory/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1760: RuntimeWarning: divide by zero encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/lucasb/anaconda3/envs/inventory/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1760: RuntimeWarning: invalid value encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/lucasb/anaconda3/envs/inventory/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1760: RuntimeWarning: divide by zero encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/lucasb/anaconda3/envs/inventory/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1760: RuntimeWarning: invalid value encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/lucasb/anaconda3/envs/inventory/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1760: RuntimeWarning: divide by zero encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/lucasb/anaconda3/envs/inventory/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1760: RuntimeWarning: invalid value encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/lucasb/anaconda3/envs/inventory/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1760: RuntimeWarning: divide by zero encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/lucasb/anaconda3/envs/inventory/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1760: RuntimeWarning: invalid value encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/lucasb/anaconda3/envs/inventory/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1760: RuntimeWarning: divide by zero encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/lucasb/anaconda3/envs/inventory/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1760: RuntimeWarning: invalid value encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/lucasb/anaconda3/envs/inventory/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1760: RuntimeWarning: divide by zero encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/lucasb/anaconda3/envs/inventory/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1760: RuntimeWarning: invalid value encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/lucasb/anaconda3/envs/inventory/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1760: RuntimeWarning: divide by zero encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/lucasb/anaconda3/envs/inventory/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1760: RuntimeWarning: invalid value encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/lucasb/anaconda3/envs/inventory/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1760: RuntimeWarning: divide by zero encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/lucasb/anaconda3/envs/inventory/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1760: RuntimeWarning: invalid value encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/lucasb/anaconda3/envs/inventory/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1760: RuntimeWarning: divide by zero encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/lucasb/anaconda3/envs/inventory/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1760: RuntimeWarning: invalid value encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/lucasb/anaconda3/envs/inventory/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1760: RuntimeWarning: divide by zero encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/lucasb/anaconda3/envs/inventory/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1760: RuntimeWarning: invalid value encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/lucasb/anaconda3/envs/inventory/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1760: RuntimeWarning: divide by zero encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/lucasb/anaconda3/envs/inventory/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1760: RuntimeWarning: invalid value encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/lucasb/anaconda3/envs/inventory/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1760: RuntimeWarning: divide by zero encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/lucasb/anaconda3/envs/inventory/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1760: RuntimeWarning: invalid value encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/lucasb/anaconda3/envs/inventory/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1760: RuntimeWarning: divide by zero encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/lucasb/anaconda3/envs/inventory/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1760: RuntimeWarning: invalid value encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/lucasb/anaconda3/envs/inventory/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1760: RuntimeWarning: divide by zero encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/lucasb/anaconda3/envs/inventory/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1760: RuntimeWarning: invalid value encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/lucasb/anaconda3/envs/inventory/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1760: RuntimeWarning: divide by zero encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/lucasb/anaconda3/envs/inventory/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1760: RuntimeWarning: invalid value encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/lucasb/anaconda3/envs/inventory/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1760: RuntimeWarning: divide by zero encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/lucasb/anaconda3/envs/inventory/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1760: RuntimeWarning: invalid value encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/lucasb/anaconda3/envs/inventory/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1760: RuntimeWarning: divide by zero encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/lucasb/anaconda3/envs/inventory/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1760: RuntimeWarning: invalid value encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/lucasb/anaconda3/envs/inventory/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1760: RuntimeWarning: divide by zero encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/lucasb/anaconda3/envs/inventory/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1760: RuntimeWarning: invalid value encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/lucasb/anaconda3/envs/inventory/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1760: RuntimeWarning: divide by zero encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/lucasb/anaconda3/envs/inventory/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1760: RuntimeWarning: invalid value encountered in true_divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)

# %% [markdown]
# Compare original data and samples.

# %%
fig, ax = plt.subplots(facecolor="white")
for i in range(len(SKUs)):
    plt.plot(X, y_impute[i]/1e5,alpha=0.2,color="tab:blue")
plt.plot(X,samples,alpha=0.02,color="Grey")
plt.plot(100, 100,alpha=0.3,color="tab:blue",label="data")
plt.plot(100,100,alpha=0.3,color="Grey",label="sample")
ax.xaxis.set_minor_locator(MultipleLocator(5))
plt.xlim(0,120)
plt.ylim(0,2.5)
plt.xlabel(r"week")
plt.ylabel(r"customer orders [$\times 10^5$]")
plt.legend(loc=2,frameon=False,fontsize=8)
plt.tight_layout()
plt.savefig("gaussian_sampling_2.png",dpi=480)
plt.show()

# %% [markdown]
# Combine empirical data with capped-dual index policy.

# %% [markdown]
# # Apply CDI policy to empirical demand data

# %%
#np.random.seed(10)

ce = 20
cr = 0
le = 0
lr = 2
h = 5
b = 495

T = max_weeks

u1_arr = np.arange(5)
u2_arr = np.arange(6)
u3_arr = np.arange(5)

# %%
cdi_tuples = []

for i in range(len(samples[0])//2):
    print("iteration %d"%i)
    demand_distribution = [samples[j][i] for j in range(len(samples))]

    optimal_u1, optimal_u2, optimal_u3 = capped_dual_index_parameters(u1_arr,
                                                                      u2_arr,
                                                                      u3_arr,
                                                                      ce, 
                                                                      cr, 
                                                                      le, 
                                                                      lr,
                                                                      h, 
                                                                      b, 
                                                                      T,
                                                                      demand_distribution)
    cdi_tuples.append((optimal_u1, optimal_u2, optimal_u3))
# Out:
# iteration 0
# minimum cost: 13.1649007811808
# u1*: 2
# u2*: 3
# u3*: 1
# iteration 1
# minimum cost: 10.7816777903726
# u1*: 1
# u2*: 3
# u3*: 1
# iteration 2
# minimum cost: 10.103656307148185
# u1*: 1
# u2*: 3
# u3*: 2
# iteration 3
# minimum cost: 13.063887012857325
# u1*: 0
# u2*: 4
# u3*: 1
# iteration 4
# minimum cost: 12.71121211190508
# u1*: 2
# u2*: 3
# u3*: 1
# iteration 5
# minimum cost: 12.903746816154069
# u1*: 2
# u2*: 3
# u3*: 1
# iteration 6
# minimum cost: 10.74879276186995
# u1*: 1
# u2*: 2
# u3*: 1
# iteration 7
# minimum cost: 12.793927401658754
# u1*: 0
# u2*: 4
# u3*: 1
# iteration 8
# minimum cost: 13.378888466027156
# u1*: 2
# u2*: 3
# u3*: 1
# iteration 9
# minimum cost: 12.967970760573364
# u1*: 2
# u2*: 3
# u3*: 1
# iteration 10
# minimum cost: 12.744138244562164
# u1*: 2
# u2*: 3
# u3*: 1
# iteration 11
# minimum cost: 12.852087476130318
# u1*: 2
# u2*: 3
# u3*: 1
# iteration 12
# minimum cost: 14.568211916018031
# u1*: 2
# u2*: 3
# u3*: 1
# iteration 13
# minimum cost: 12.647235940278335
# u1*: 0
# u2*: 4
# u3*: 2
# iteration 14
# minimum cost: 9.178612161199533
# u1*: 1
# u2*: 3
# u3*: 1
# iteration 15
# minimum cost: 12.638886027638874
# u1*: 2
# u2*: 3
# u3*: 1
# iteration 16
# minimum cost: 9.975826872114094
# u1*: 1
# u2*: 3
# u3*: 1
# iteration
                          capped_dual_index=True,
                          demand_distribution=demand_distribution)

    S.simulate()  
    
    CDI_cost_arr.append(S.total_cost/T)
    
    print("average cost (capped dual index):", S.total_cost/T)
# Out:
# iteration 0
# average cost (capped dual index): 12.301697750035512
# iteration 1
# average cost (capped dual index): 12.244666466416218
# iteration 2
# average cost (capped dual index): 18.50495509802281
# iteration 3
# average cost (capped dual index): 12.991540430999883
# iteration 4
# average cost (capped dual index): 15.72451944417191
# iteration 5
# average cost (capped dual index): 12.863651949030904
# iteration 6
# average cost (capped dual index): 12.250700359082693
# iteration 7
# average cost (capped dual index): 12.517808123101098
# iteration 8
# average cost (capped dual index): 13.093052656571405
# iteration 9
# average cost (capped dual index): 18.09737147685071
# iteration 10
# average cost (capped dual index): 12.224656404978731
# iteration 11
# average cost (capped dual index): 12.507478769746275
# iteration 12
# average cost (capped dual index): 12.69662038170194
# iteration 13
# average cost (capped dual index): 12.971995564788676
# iteration 14
# average cost (capped dual index): 12.498944135870941
# iteration 15
# average cost (capped dual index): 12.878927676631998
# iteration 16
# average cost (capped dual index): 12.097719614431899
# iteration 17
# average cost (capped dual index): 12.794773442073831
# iteration 18
# average cost (capped dual index): 12.741474587174574
# iteration 19
# average cost (capped dual index): 12.37995550072156
# iteration 20
# average cost (capped dual index): 12.996948598128506
# iteration 21
# average cost (capped dual index): 12.623803549164306
# iteration 22
# average cost (capped dual index): 12.338290371369714
# iteration 23
# average cost (capped dual index): 12.303391499369301
# iteration 24
# average cost (capped dual index): 13.394458665054787
# iteration 25
# average cost (capped dual index): 15.315703624735935
# iteration 26
# average cost (capped dual index): 12.42448418313096
# iteration 27
# average cost (capped dual index): 12.804461050994735
# iteration 28
# average cost (capped dual index): 11.867575458091466
# iteration 29
# average cost (capped dual index): 12.6686302318207
# iteration 30
# average cost (capped dual index): 14.945429900385072
# iteration 31
# average cost (capped dual index): 14.2795058940774
# iteration 32
# average cost (capped dual index): 14.282588542084241
# iteration 33
# average cost (capped dual index): 12.7742192406215
# iteration 34
# average cost (capped dual index): 12.504605137381368
# iteration 35
# average cost (capped dual index): 12.553853568339978
# iteration 36
# average cost (capped dual index): 12.864384913727811
# iteration 37
# average cost (capped dual index): 12.758370640620447
# iteration 38
# average cost (capped dual index): 13.970371096390416
# iteration 39
# average cost (capped dual index): 13.197978577534693
# iteration 40
# average cost (capped dual index): 12.415940695665578
# iteration 41
# average cost (capped dual index): 12.658665029822808
# iteration 42
# average cost (capped dual index): 12.435141543494263
# iteration 43
# average cost (capped dual index): 15.762172121686843
# iteration 44
# average cost (capped dual index): 14.441277670405363
# iteration 45
# average cost (capped dual index): 13.076326943414427
# iteration 46
# average cost (capped dual index): 12.66564269795112
# iteration 47
# average cost (capped dual index): 12.664953754871272
# iteration 48
# average cost (capped dual index): 14.295251828943972
# iteration 49
# average cost (capped dual index): 15.187394062042033
# iteration 50
# average cost (capped dual index): 12.571797338685803
# iteration 51
# average cost (capped dual index): 12.48510954685496
# iteration 52
# average cost (capped dual index): 12.657700341151969
# iteration 53
# average cost (capped dual index): 13.077651802218172
# iteration 54
# average cost (capped dual index): 15.495697061071294
# iteration 55
# average cost (capped dual index): 13.23385731379887
# iteration 56
# average cost (capped dual index): 12.819978488547388
# iteration 57
# average cost (capped dual index): 12.599399163602284
# iteration 58
# average cost (capped dual index): 13.10288316343789
# iteration 59
# average cost (capped dual index): 13.068131187778498
# iteration 60
# average cost (capped dual index): 12.499219743268181
# iteration 61
# average cost (capped dual index): 12.688716840534516
# iteration 62
# average cost (capped dual index): 12.701236137271428
# iteration 63
# average cost (capped dual index): 12.418848783640174
# iteration 64
# average cost (capped dual index): 12.742149814499173
# iteration 65
# average cost (capped dual index): 13.535749448337285
# iteration 66
# average cost (capped dual index): 13.272677929775165
# iteration 67
# average cost (capped dual index): 13.475634292884878
# iteration 68
# average cost (capped dual index): 12.672092583959794
# iteration 69
# average cost (capped dual index): 13.863694141082881
# iteration 70
# average cost (capped dual index): 12.856256139744966
# iteration 71
# average cost (capped dual index): 16.58034968999477
# iteration 72
# average cost (capped dual index): 12.776080473342414
# iteration 73
# average cost (capped dual index): 13.262570553581606
# iteration 74
# average cost (capped dual index): 12.406578430835422
# iteration 75
# average cost (capped dual index): 12.967049217757724
# iteration 76
# average cost (capped dual index): 14.957425896945741
# iteration 77
# average cost (capped dual index): 12.452127925741587
# iteration 78
# average cost (capped dual index): 12.679643981203208
# iteration 79
# average cost (capped dual index): 12.098674309524643
# iteration 80
# average cost (capped dual index): 12.476446277825616
# iteration 81
# average cost (capped dual index): 13.773091779895571
# iteration 82
# average cost (capped dual index): 14.164687900065209
# iteration 83
# average cost (capped dual index): 12.619745547294038
# iteration 84
# average cost (capped dual index): 12.563445805730332
# iteration 85
# average cost (capped dual index): 16.0680569914617
# iteration 86
# average cost (capped dual index): 12.530635052653393
# iteration 87
# average cost (capped dual index): 12.640476454321988
# iteration 88
# average cost (capped dual index): 13.263772544558321
# iteration 89
# average cost (capped dual index): 12.735265492081933
# iteration 90
# average cost (capped dual index): 12.841469909282797
# iteration 91
# average cost (capped dual index): 12.12607394526949
# iteration 92
# average cost (capped dual index): 12.62681586964611
# iteration 93
# average cost (capped dual index): 12.476097519055768
# iteration 94
# average cost (capped dual index): 12.62806405784774
# iteration 95
# average cost (capped dual index): 12.404707629725937
# iteration 96
# average cost (capped dual index): 12.64660533538642
# iteration 97
# average cost (capped dual index): 12.26033295347314
# iteration 98
# average cost (capped dual index): 14.633252164215646
# iteration 99
# average cost (capped dual index): 12.546653139248185
# iteration 100
# average cost (capped dual index): 12.694984558416792
# iteration 101
# average cost (capped dual index): 12.059952448251801
# iteration 102
# average cost (capped dual index): 12.646460952802622
# iteration 103
# average cost (capped dual index): 16.262431390985345
# iteration 104
# average cost (capped dual index): 12.300335760298687
# iteration 105
# average cost (capped dual index): 12.867058175601805
# iteration 106
# average cost (capped dual index): 12.977799843001756
# iteration 107
# average cost (capped dual index): 12.324556585148247
# iteration 108
# average cost (capped dual index): 12.730783330364
# iteration 109
# average cost (capped dual index): 12.28900668209958
# iteration 110
# average cost (capped dual index): 12.208577859408653
# iteration 111
# average cost (capped dual index): 12.427433061242269
# iteration 112
# average cost (capped dual index): 12.68944784625752
# iteration 113
# average cost (capped dual index): 12.955156595342238
# iteration 114
# average cost (capped dual index): 12.672761630234394
# iteration 115
# average cost (capped dual index): 12.865888038504655
# iteration 116
# average cost (capped dual index): 16.837533664148697
# iteration 117
# average cost (capped dual index): 12.73508400275298
# iteration 118
# average cost (capped dual index): 14.367157709360422
# iteration 119
# average cost (capped dual index): 14.281947388155942
# iteration 120
# average cost (capped dual index): 13.26773551561135
# iteration 121
# average cost (capped dual index): 13.02236846077489
# iteration 122
# average cost (capped dual index): 12.7954672341142
# iteration 123
# average cost (capped dual index): 13.25450484418633
# iteration 124
# average cost (capped dual index): 12.654085529394544
# iteration 125
# average cost (capped dual index): 12.394609841832724
# iteration 126
# average cost (capped dual index): 12.572910373888568
# iteration 127
# average cost (capped dual index): 12.588577395096646
# iteration 128
# average cost (capped dual index): 13.465288291526019
# iteration 129
# average cost (capped dual index): 15.429069739454985
# iteration 130
# average cost (capped dual index): 14.618412465178947
# iteration 131
# average cost (capped dual index): 14.76269264524082
# iteration 132
# average cost (capped dual index): 12.655355575142508
# iteration 133
# average cost (capped dual index): 12.717842314986463
# iteration 134
# average cost (capped dual index): 12.530841404657055
# iteration 135
# average cost (capped dual index): 12.792605707711488
# iteration 136
# average cost (capped dual index): 12.716622055108584
# iteration 137
# average cost (capped dual index): 12.823301359865692
# iteration 138
# average cost (capped dual index): 12.779064913866401
# iteration 139
# average cost (capped dual index): 12.914515293359756
# iteration 140
# average cost (capped dual index): 13.224178463190363
# iteration 141
# average cost (capped dual index): 12.618780130452175
# iteration 142
# average cost (capped dual index): 12.145713740270489
# iteration 143
# average cost (capped dual index): 12.865153789712105
# iteration 144
# average cost (capped dual index): 13.893434132837637
# iteration 145
# average cost (capped dual index): 13.155000625394038
# iteration 146
# average cost (capped dual index): 12.593008824866418
# iteration 147
# average cost (capped dual index): 12.722555025956979
# iteration 148
# average cost (capped dual index): 12.91514160596597
# iteration 149
# average cost (capped dual index): 13.261714178850964
# iteration 150
# average cost (capped dual index): 14.881629204700467
# iteration 151
# average cost (capped dual index): 12.891192047577057
# iteration 152
# average cost (capped dual index): 12.568747569028506
# iteration 153
# average cost (capped dual index): 18.090642336246386
# iteration 154
# average cost (capped dual index): 12.888581792845432
# iteration 155
# average cost (capped dual index): 12.371376784671227
# iteration 156
# average cost (capped dual index): 13.251959656035682
# iteration 157
# average cost (capped dual index): 12.273331823709253
# iteration 158
# average cost (capped dual index): 12.821792392038493
# iteration 159
# average cost (capped dual index): 12.83209119387338
# iteration 160
# average cost (capped dual index): 12.766151867033486
# iteration 161
# average cost (capped dual index): 12.894311203938503
# iteration 162
# average cost (capped dual index): 12.565721178631845
# iteration 163
# average cost (capped dual index): 12.203679645836619
# iteration 164
# average cost (capped dual index): 12.475338993700518
# iteration 165
# average cost (capped dual index): 13.05370442837039
# iteration 166
# average cost (capped dual index): 12.634698476754732
# iteration 167
# average cost (capped dual index): 13.340363076604898
# iteration 168
# average cost (capped dual index): 17.104886199500136
# iteration 169
# average cost (capped dual index): 12.76793214855201
# iteration 170
# average cost (capped dual index): 14.544382721611537
# iteration 171
# average cost (capped dual index): 12.632258288323085
# iteration 172
# average cost (capped dual index): 12.639372555545213
# iteration 173
# average cost (capped dual index): 12.87890127944274
# iteration 174
# average cost (capped dual index): 12.620385003605016
# iteration 175
# average cost (capped dual index): 12.386502638646673
# iteration 176
# average cost (capped dual index): 12.609953542420246
# iteration 177
# average cost (capped dual index): 12.1286642485385
# iteration 178
# average cost (capped dual index): 12.803966957237556
# iteration 179
# average cost (capped dual index): 12.920707384174746
# iteration 180
# average cost (capped dual index): 14.246535878426057
# iteration 181
# average cost (capped dual index): 12.243243611229566
# iteration 182
# average cost (capped dual index): 13.05779894954731
# iteration 183
# average cost (capped dual index): 14.12362417553651
# iteration 184
# average cost (capped dual index): 12.630710175252618
# iteration 185
# average cost (capped dual index): 12.013452734445908
# iteration 186
# average cost (capped dual index): 12.99942837579545
# iteration 187
# average cost (capped dual index): 15.373018144781431
# iteration 188
# average cost (capped dual index): 11.837241222008709
# iteration 189
# average cost (capped dual index): 12.520840615874215
# iteration 190
# average cost (capped dual index): 13.084312370681955
# iteration 191
# average cost (capped dual index): 12.984131219722592
# iteration 192
# average cost (capped dual index): 12.621238838786242
# iteration 193
# average cost (capped dual index): 13.035314341795537
# iteration 194
# average cost (capped dual index): 13.52810322955848
# iteration 195
# average cost (capped dual index): 12.519483482719894
# iteration 196
# average cost (capped dual index): 12.127667053937493
# iteration 197
# average cost (capped dual index): 12.460352012021152
# iteration 198
# average cost (capped dual index): 12.719444712516038
# iteration 199
# average cost (capped dual index): 12.87648195480742
# iteration 200
# average cost (capped dual index): 12.636356558941195
# iteration 201
# average cost (capped dual index): 12.409163032552772
# iteration 202
# average cost (capped dual index): 12.689090612007515
# iteration 203
# average cost (capped dual index): 12.747826136123107
# iteration 204
# average cost (capped dual index): 12.682752437004789
# iteration 205
# average cost (capped dual index): 12.583984561165904
# iteration 206
# average cost (capped dual index): 12.465360870070112
# iteration 207
# average cost (capped dual index): 14.12710881330501
# iteration 208
# average cost (capped dual index): 13.393114971802722
# iteration 209
# average cost (capped dual index): 12.799234943584333
# iteration 210
# average cost (capped dual index): 14.31156200148635
# iteration 211
# average cost (capped dual index): 12.772483450436615
# iteration 212
# average cost (capped dual index): 13.850176783486463
# iteration 213
# average cost (capped dual index): 13.2086104713723
# iteration 214
# average cost (capped dual index): 12.801019767643428
# iteration 215
# average cost (capped dual index): 12.86301935902378
# iteration 216
# average cost (capped dual index): 12.399770778015466
# iteration 217
# average cost (capped dual index): 14.073779454904844
# iteration 218
# average cost (capped dual index): 13.910085324504792
# iteration 219
# average cost (capped dual index): 18.90481414363048
# iteration 220
# average cost (capped dual index): 12.389386923566464
# iteration 221
# average cost (capped dual index): 12.43622254748164
# iteration 222
# average cost (capped dual index): 12.39138364982717
# iteration 223
# average cost (capped dual index): 13.621218628411357
# iteration 224
# average cost (capped dual index): 12.747960657088537
# iteration 225
# average cost (capped dual index): 12.701418165599465
# iteration 226
# average cost (capped dual index): 14.135018358352692
# iteration 227
# average cost (capped dual index): 13.085195212186257
# iteration 228
# average cost (capped dual index): 13.909203829773002
# iteration 229
# average cost (capped dual index): 13.45330059822319
# iteration 230
# average cost (capped dual index): 13.031428424458547
# iteration 231
# average cost (capped dual index): 12.848326449777586
# iteration 232
# average cost (capped dual index): 12.755164557193677
# iteration 233
# average cost (capped dual index): 12.521055871888228
# iteration 234
# average cost (capped dual index): 12.78648829095038
# iteration 235
# average cost (capped dual index): 12.938707857550824
# iteration 236
# average cost (capped dual index): 12.535266969625349
# iteration 237
# average cost (capped dual index): 13.627949843976078
# iteration 238
# average cost (capped dual index): 13.043714092129019
# iteration 239
# average cost (capped dual index): 12.145095442751943
# iteration 240
# average cost (capped dual index): 13.085160859699664
# iteration 241
# average cost (capped dual index): 12.510606847849918
# iteration 242
# average cost (capped dual index): 12.511044522552636
# iteration 243
# average cost (capped dual index): 12.570777558023172
# iteration 244
# average cost (capped dual index): 13.734550395930984
# iteration 245
# average cost (capped dual index): 12.687678702806874
# iteration 246
# average cost (capped dual index): 13.083232575053168
# iteration 247
# average cost (capped dual index): 13.700236774200308
# iteration 248
# average cost (capped dual index): 12.579577256967228
# iteration 249
# average cost (capped dual index): 12.463813632491782
# iteration 250
# average cost (capped dual index): 12.768073830339558
# iteration 251
# average cost (capped dual index): 12.411444114509603
# iteration 252
# average cost (capped dual index): 12.413982874415051
# iteration 253
# average cost (capped dual index): 12.9216713687709
# iteration 254
# average cost (capped dual index): 12.239280508304521
# iteration 255
# average cost (capped dual index): 12.630315836219836
# iteration 256
# average cost (capped dual index): 13.696512925388822
# iteration 257
# average cost (capped dual index): 12.326988472112262
# iteration 258
# average cost (capped dual index): 14.85410321604013
# iteration 259
# average cost (capped dual index): 13.000785199491174
# iteration 260
# average cost (capped dual index): 13.982162783330477
# iteration 261
# average cost (capped dual index): 12.513668065079656
# iteration 262
# average cost (capped dual index): 12.627029406943265
# iteration 263
# average cost (capped dual index): 13.974718341787904
# iteration 264
# average cost (capped dual index): 12.910501294407405
# iteration 265
# average cost (capped dual index): 13.203684516405758
# iteration 266
# average cost (capped dual index): 12.375074979413798
# iteration 267
# average cost (capped dual index): 12.498857265264359
# iteration 268
# average cost (capped dual index): 12.618259866909929
# iteration 269
# average cost (capped dual index): 12.592642191746492
# iteration 270
# average cost (capped dual index): 13.42706500040119
# iteration 271
# average cost (capped dual index): 12.193049519740514
# iteration 272
# average cost (capped dual index): 12.445285397008837
# iteration 273
# average cost (capped dual index): 13.033064117769111
# iteration 274
# average cost (capped dual index): 12.063790745770802
# iteration 275
# average cost (capped dual index): 11.970912129477837
# iteration 276
# average cost (capped dual index): 12.48730444038062
# iteration 277
# average cost (capped dual index): 12.607807833328792
# iteration 278
# average cost (capped dual index): 12.339681212814662
# iteration 279
# average cost (capped dual index): 13.11913850661664
# iteration 280
# average cost (capped dual index): 13.180417076576767
# iteration 281
# average cost (capped dual index): 12.50982850861891
# iteration 282
# average cost (capped dual index): 13.160257351920134
# iteration 283
# average cost (capped dual index): 12.962566761355966
# iteration 284
# average cost (capped dual index): 12.472508140917
# iteration 285
# average cost (capped dual index): 13.772711638754258
# iteration 286
# average cost (capped dual index): 12.684814796372043
# iteration 287
# average cost (capped dual index): 13.197250513321519
# iteration 288
# average cost (capped dual index): 12.669827369095785
# iteration 289
# average cost (capped dual index): 13.595702319422827
# iteration 290
# average cost (capped dual index): 12.913754231936649
# iteration 291
# average cost (capped dual index): 13.902750479269466
# iteration 292
# average cost (capped dual index): 12.421163085448354
# iteration 293
# average cost (capped dual index): 14.086229848390456
# iteration 294
# average cost (capped dual index): 16.439665343619836
# iteration 295
# average cost (capped dual index): 13.898199347987218
# iteration 296
# average cost (capped dual index): 12.907482286807927
# iteration 297
# average cost (capped dual index): 12.392173578377264
# iteration 298
# average cost (capped dual index): 12.899454638568368
# iteration 299
# average cost (capped dual index): 12.987812089433456
# iteration 300
# average cost (capped dual index): 12.618244311752658
# iteration 301
# average cost (capped dual index): 12.504210461380667
# iteration 302
# average cost (capped dual index): 15.577640734423152
# iteration 303
# average cost (capped dual index): 13.47670374532988
# iteration 304
# average cost (capped dual index): 13.947101173508324
# iteration 305
# average cost (capped dual index): 14.007518015840269
# iteration 306
# average cost (capped dual index): 12.211841463793737
# iteration 307
# average cost (capped dual index): 12.329265545961508
# iteration 308
# average cost (capped dual index): 12.614367253154326
# iteration 309
# average cost (capped dual index): 12.763864722945026
# iteration 310
# average cost (capped dual index): 12.497656699202903
# iteration 311
# average cost (capped dual index): 12.943244426878238
# iteration 312
# average cost (capped dual index): 12.728352250973819
# iteration 313
# average cost (capped dual index): 13.921224695345886
# iteration 314
# average cost (capped dual index): 12.806218194549716
# iteration 315
# average cost (capped dual index): 14.943365642382366
# iteration 316
# average cost (capped dual index): 12.529705054569952
# iteration 317
# average cost (capped dual index): 13.053036805802751
# iteration 318
# average cost (capped dual index): 12.595803621707423
# iteration 319
# average cost (capped dual index): 12.67733039359683
# iteration 320
# average cost (capped dual index): 12.993239664526751
# iteration 321
# average cost (capped dual index): 12.961915271395583
# iteration 322
# average cost (capped dual index): 12.619106046075434
# iteration 323
# average cost (capped dual index): 14.279552977492118
# iteration 324
# average cost (capped dual index): 12.833235602624704
# iteration 325
# average cost (capped dual index): 12.777632523705018
# iteration 326
# average cost (capped dual index): 15.04043040160185
# iteration 327
# average cost (capped dual index): 17.403785428641687
# iteration 328
# average cost (capped dual index): 13.363819280230729
# iteration 329
# average cost (capped dual index): 12.065198815342379
# iteration 330
# average cost (capped dual index): 13.196519113278049
# iteration 331
# average cost (capped dual index): 12.546405644790868
# iteration 332
# average cost (capped dual index): 12.83555064515209
# iteration 333
# average cost (capped dual index): 12.40725899395231
# iteration 334
# average cost (capped dual index): 14.645748049814314
# iteration 335
# average cost (capped dual index): 12.892332709821519
# iteration 336
# average cost (capped dual index): 12.373833405099555
# iteration 337
# average cost (capped dual index): 12.589508618351537
# iteration 338
# average cost (capped dual index): 14.092674174014347
# iteration 339
# average cost (capped dual index): 12.976564680923909
# iteration 340
# average cost (capped dual index): 12.681794662705927
# iteration 341
# average cost (capped dual index): 12.868793698023449
# iteration 342
# average cost (capped dual index): 13.164372448817154
# iteration 343
# average cost (capped dual index): 12.820055927451056
# iteration 344
# average cost (capped dual index): 12.392482084355823
# iteration 345
# average cost (capped dual index): 12.193407547444943
# iteration 346
# average cost (capped dual index): 12.361793696827164
# iteration 347
# average cost (capped dual index): 13.014092817697925
# iteration 348
# average cost (capped dual index): 14.036168347956254
# iteration 349
# average cost (capped dual index): 13.192139335896877
# iteration 350
# average cost (capped dual index): 13.262985629948593
# iteration 351
# average cost (capped dual index): 15.123655386597154
# iteration 352
# average cost (capped dual index): 12.206147863066528
# iteration 353
# average cost (capped dual index): 12.571601070742592
# iteration 354
# average cost (capped dual index): 12.626561019780038
# iteration 355
# average cost (capped dual index): 13.86178116124144
# iteration 356
# average cost (capped dual index): 12.285051487676796
# iteration 357
# average cost (capped dual index): 12.601706674762847
# iteration 358
# average cost (capped dual index): 12.675141504120468
# iteration 359
# average cost (capped dual index): 16.478024459345995
# iteration 360
# average cost (capped dual index): 12.817536568038111
# iteration 361
# average cost (capped dual index): 13.102714268968452
# iteration 362
# average cost (capped dual index): 12.663338951589557
# iteration 363
# average cost (capped dual index): 12.765803795009349
# iteration 364
# average cost (capped dual index): 12.780305826767258
# iteration 365
# average cost (capped dual index): 12.508156433482569
# iteration 366
# average cost (capped dual index): 13.134503181920469
# iteration 367
# average cost (capped dual index): 12.520388051829867
# iteration 368
# average cost (capped dual index): 13.116961454622432
# iteration 369
# average cost (capped dual index): 12.479862355536872
# iteration 370
# average cost (capped dual index): 16.112481678208788
# iteration 371
# average cost (capped dual index): 12.647608539633735
# iteration 372
# average cost (capped dual index): 12.43744138563476
# iteration 373
# average cost (capped dual index): 13.24923274903144
# iteration 374
# average cost (capped dual index): 13.561899037142423
# iteration 375
# average cost (capped dual index): 12.61025123330758
# iteration 376
# average cost (capped dual index): 12.69338931012381
# iteration 377
# average cost (capped dual index): 12.43582019293306
# iteration 378
# average cost (capped dual index): 12.471774198967244
# iteration 379
# average cost (capped dual index): 15.685164528107315
# iteration 380
# average cost (capped dual index): 12.654020696233067
# iteration 381
# average cost (capped dual index): 12.093851497264948
# iteration 382
# average cost (capped dual index): 12.885328248965127
# iteration 383
# average cost (capped dual index): 12.270584057174284
# iteration 384
# average cost (capped dual index): 13.656543266937364
# iteration 385
# average cost (capped dual index): 12.39382880457279
# iteration 386
# average cost (capped dual index): 12.63578175392071
# iteration 387
# average cost (capped dual index): 13.346585072918211
# iteration 388
# average cost (capped dual index): 12.473710643997897
# iteration 389
# average cost (capped dual index): 15.952526244111409
# iteration 390
# average cost (capped dual index): 12.730484185227775
# iteration 391
# average cost (capped dual index): 12.70554879444977
# iteration 392
# average cost (capped dual index): 12.381172616514366
# iteration 393
# average cost (capped dual index): 12.998708546065632
# iteration 394
# average cost (capped dual index): 12.85699386165552
# iteration 395
# average cost (capped dual index): 13.08354667640094
# iteration 396
# average cost (capped dual index): 12.42386470384527
# iteration 397
# average cost (capped dual index): 12.151830011711418
# iteration 398
# average cost (capped dual index): 13.010414620532082
# iteration 399
# average cost (capped dual index): 12.662005244817337
# iteration 400
# average cost (capped dual index): 13.546989502874089
# iteration 401
# average cost (capped dual index): 12.349446266777212
# iteration 402
# average cost (capped dual index): 12.838748406509582
# iteration 403
# average cost (capped dual index): 16.535821456078025
# iteration 404
# average cost (capped dual index): 12.696442533964685
# iteration 405
# average cost (capped dual index): 15.260383768754629
# iteration 406
# average cost (capped dual index): 12.453966494493779
# iteration 407
# average cost (capped dual index): 13.83032493727485
# iteration 408
# average cost (capped dual index): 12.572585712989301
# iteration 409
# average cost (capped dual index): 13.190677528105478
# iteration 410
# average cost (capped dual index): 13.498293846615542
# iteration 411
# average cost (capped dual index): 12.846239078865336
# iteration 412
# average cost (capped dual index): 14.353669419467968
# iteration 413
# average cost (capped dual index): 13.06532012793155
# iteration 414
# average cost (capped dual index): 12.60579754743267
# iteration 415
# average cost (capped dual index): 12.652662566103691
# iteration 416
# average cost (capped dual index): 12.234325507340083
# iteration 417
# average cost (capped dual index): 12.686824835591288
# iteration 418
# average cost (capped dual index): 12.96595267710889
# iteration 419
# average cost (capped dual index): 12.46470339913998
# iteration 420
# average cost (capped dual index): 12.680134483456525
# iteration 421
# average cost (capped dual index): 13.14807779716802
# iteration 422
# average cost (capped dual index): 12.512811724205255
# iteration 423
# average cost (capped dual index): 12.086437395189128
# iteration 424
# average cost (capped dual index): 16.310303322350318
# iteration 425
# average cost (capped dual index): 12.43955527702976
# iteration 426
# average cost (capped dual index): 12.785095718780385
# iteration 427
# average cost (capped dual index): 13.074696895314714
# iteration 428
# average cost (capped dual index): 13.018814244621623
# iteration 429
# average cost (capped dual index): 12.49980306272299
# iteration 430
# average cost (capped dual index): 13.099070852336734
# iteration 431
# average cost (capped dual index): 12.284777971983008
# iteration 432
# average cost (capped dual index): 12.46386281982646
# iteration 433
# average cost (capped dual index): 12.203125748718273
# iteration 434
# average cost (capped dual index): 12.56699981488367
# iteration 435
# average cost (capped dual index): 12.890443633124004
# iteration 436
# average cost (capped dual index): 12.575402761440971
# iteration 437
# average cost (capped dual index): 13.327227878387863
# iteration 438
# average cost (capped dual index): 12.69715113935567
# iteration 439
# average cost (capped dual index): 12.729515432868668
# iteration 440
# average cost (capped dual index): 12.70182563761102
# iteration 441
# average cost (capped dual index): 13.286569971642724
# iteration 442
# average cost (capped dual index): 12.84393065966004
# iteration 443
# average cost (capped dual index): 13.293577784485597
# iteration 444
# average cost (capped dual index): 12.630473147471681
# iteration 445
# average cost (capped dual index): 12.828652157180958
# iteration 446
# average cost (capped dual index): 13.42029930318512
# iteration 447
# average cost (capped dual index): 12.295763387883786
# iteration 448
# average cost (capped dual index): 12.65310380363293
# iteration 449
# average cost (capped dual index): 12.711871946268252
# iteration 450
# average cost (capped dual index): 13.183300235541457
# iteration 451
# average cost (capped dual index): 12.66410682633984
# iteration 452
# average cost (capped dual index): 13.490987788613268
# iteration 453
# average cost (capped dual index): 12.752696174175439
# iteration 454
# average cost (capped dual index): 12.891951676649276
# iteration 455
# average cost (capped dual index): 12.799276467481475
# iteration 456
# average cost (capped dual index): 13.041042552654861
# iteration 457
# average cost (capped dual index): 15.54221466029359
# iteration 458
# average cost (capped dual index): 13.663844985596162
# iteration 459
# average cost (capped dual index): 12.500877439421828
# iteration 460
# average cost (capped dual index): 12.396735236247906
# iteration 461
# average cost (capped dual index): 12.597413042713544
# iteration 462
# average cost (capped dual index): 13.419273649222271
# iteration 463
# average cost (capped dual index): 14.087759998956363
# iteration 464
# average cost (capped dual index): 12.424051926545877
# iteration 465
# average cost (capped dual index): 12.281914054923048
# iteration 466
# average cost (capped dual index): 12.342004721522352
# iteration 467
# average cost (capped dual index): 12.667716171047763
# iteration 468
# average cost (capped dual index): 16.593828167090056
# iteration 469
# average cost (capped dual index): 12.581298825577715
# iteration 470
# average cost (capped dual index): 13.042036040166893
# iteration 471
# average cost (capped dual index): 13.640552922541822
# iteration 472
# average cost (capped dual index): 12.145762832561017
# iteration 473
# average cost (capped dual index): 12.383272802476645
# iteration 474
# average cost (capped dual index): 12.469597211965901
# iteration 475
# average cost (capped dual index): 12.785984468942848
# iteration 476
# average cost (capped dual index): 14.850370548276272
# iteration 477
# average cost (capped dual index): 17.985644734746767
# iteration 478
# average cost (capped dual index): 12.407493291801911
# iteration 479
# average cost (capped dual index): 13.098162792091486
# iteration 480
# average cost (capped dual index): 12.450281727531474
# iteration 481
# average cost (capped dual index): 14.515317784786765
# iteration 482
# average cost (capped dual index): 12.350001246266785
# iteration 483
# average cost (capped dual index): 12.859817741529449
# iteration 484
# average cost (capped dual index): 12.82385167239192
# iteration 485
# average cost (capped dual index): 12.631993994634454
# iteration 486
# average cost (capped dual index): 16.085066651522506
# iteration 487
# average cost (capped dual index): 13.003494610661322
# iteration 488
# average cost (capped dual index): 12.650463239313881
# iteration 489
# average cost (capped dual index): 12.541946522303299
# iteration 490
# average cost (capped dual index): 12.816589678820966
# iteration 491
# average cost (capped dual index): 11.983862313371235
# iteration 492
# average cost (capped dual index): 13.17928537772164
# iteration 493
# average cost (capped dual index): 12.621940132481807
# iteration 494
# average cost (capped dual index): 12.995406425808213
# iteration 495
# average cost (capped dual index): 12.748302540270494
# iteration 496
# average cost (capped dual index): 13.721917334249396
# iteration 497
# average cost (capped dual index): 12.058220793586946
# iteration 498
# average cost (capped dual index): 12.719089125708617
# iteration 499
# average cost (capped dual index): 12.784296088189913

# %% [markdown]
# Average cost of most effective CDI policy.

# %%
print(np.mean(CDI_cost_arr),np.std(CDI_cost_arr,ddof=1))
# Out:
# 13.106504178226576 1.0492928892871807

# %%
plt.figure(facecolor="white")
plt.plot(S.inventory, '-o', label = r"inventory")
#plt.plot(S.inventory_position, '-o', label = r"inventory position")
plt.plot(S.demand, '-o', label = r"demand")
plt.xlabel(r"time")
plt.ylabel(r"value")
plt.legend(loc = 2, ncol = 1)
plt.tight_layout()
plt.savefig("msom_cdi_1.png",dpi=480)
plt.show()

# %%
plt.figure(facecolor="white")
plt.plot(S.cost, '-o', label = r"cost")
plt.plot(S.demand, '-o', label = r"demand")
plt.xlabel(r"time")
plt.ylabel(r"value")
plt.legend(loc = 2, ncol = 1)
plt.tight_layout()
plt.savefig("msom_cdi_2.png",dpi=480)
plt.show()

# %% [markdown]
# # Compare CDI with NNC-based policies

# %%
sourcing_parameters = dict(ce=20,
                           cr=0,
                           le=0,
                           lr=2,
                           h=5,
                           b=495,
                           T=max_weeks)

# %% [markdown]
# ## NNC Initialization
# Here we initialize an NNC model and set  its hyperparameters for training.

# %%
### One can experiment with different layer architectures and activations per layer
nnc_hyperparameters = dict(
    n_hidden_units = [128,64,32,16,8,4]
)

### We use celu non-linearities for the input layer, hidden layers, and output layer
nnc_hyperparameters['n_activations'] = [torch.nn.CELU(alpha=1)]*(2 + len(nnc_hyperparameters['n_hidden_units']))


fcc = DualFullyConnectedRegressionController(lr=sourcing_parameters['lr'], 
                                         le=sourcing_parameters['le'], 
                                         n_hidden_units= nnc_hyperparameters ['n_hidden_units'],
                                         activations=nnc_hyperparameters['n_activations']
                                        ) # controller neural network object

# %% [markdown]
# ## Dynamics Initialization
# To further optimize NNC (''fine tuning''), we now apply gradient propagation to the inventory evolution equation:
#
# $I_t = I_{t-1} + q^{\rm e}_{t-l_{\rm e}} + q^{\rm r}_{t-l_{\rm r}} - D_t$
#
# where $I_0, q^{\rm e}_{t},q^{\rm r}_{t}$ are NNC outputs.

# %%
dsd = DualSourcingModel(fcc, I_0=4, **sourcing_parameters) # Dual Sourcing Dynamics object

# %% [markdown]
# We preserve the best performing model in training, assuming that the neural network generalizes well during training and that our training sample is large enough.

# %%
best_loss = [np.infty]
best_model = [None]

# %%
all_training_costs = []

# %%
optimizer = torch.optim.RMSprop(#[dsd.I_0],
                                list(fcc.parameters()), 
                                lr=3*1e-3
                               )
optimizer2 = torch.optim.RMSprop([dsd.I_0],
                                #list(fcc.parameters()), 
                                lr=1e-1
                               )

# %%
fine_tuning_iterations = 100
minibatch_size = 512
random_seed = 4

t0 = time.time()
for it in range(fine_tuning_iterations):
    optimizer.zero_grad()
    optimizer2.zero_grad()
    def closure():
        dsd.reset(minibatch_size, seed=random_seed+1)
        total_costs = 0
        for i in range(dsd.T):
            current_costs, demands, current_inventories, qr, qra, qe, qea = dsd.simulate()
            total_costs = current_costs.mean() + total_costs
        all_training_costs.append(float(total_costs)/dsd.T)
        total_costs.backward()
        if it % 20 == 0:
            print(total_costs/dsd.T)
        if total_costs < best_loss[0]:
            best_loss[0] = total_costs.detach().cpu().item()
            best_model[0] = deepcopy(fcc.state_dict())
        return total_costs
    if it % 10 > 6:
        optimizer2.step(closure)
    else:
        optimizer.step(closure)
t1 = time.time()
total = t1-t0
print(total)
