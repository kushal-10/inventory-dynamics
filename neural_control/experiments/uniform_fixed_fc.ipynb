# %% [markdown]
# Contributors: Thomas Asikis, Lucas Bottcher
# ## Imports

# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('../../')
import torch
from neural_control.extended_controllers import FCController
from neural_control.extended_dynamics import SequentialDualSourcing
import plotly.express as px
import numpy as np
import matplotlib.pyplot as plt
from copy import deepcopy
from plotly import graph_objects as go
from sourcing_models.utilities import sample_trajectories_capped_dual_index, \
sample_trajectories_dual_index, sample_trajectories_single_index, sample_trajectories_tailored_base_surge
import time


from neural_control.experiments.helpers import load_experiment_conf

import matplotlib.pyplot as plt
from matplotlib import rcParams
#import seaborn as sns

# customized settings
params = {  # 'backend': 'ps',
    'font.family': 'serif',
    'font.serif': 'Latin Modern Roman',
    'font.size': 10,
    'axes.labelsize': 'medium',
    'axes.titlesize': 'medium',
    'legend.fontsize': 'medium',
    'xtick.labelsize': 'small',
    'ytick.labelsize': 'small',
    'savefig.dpi': 150,
    'text.usetex': True}
# tell matplotlib about your params
rcParams.update(params)

# %% [markdown]
# ## Sourcing Problem Parameters

# %%
sourcing_parameters_path = '../../sourcing_models/recursion_input_files/low_service_fc1_lr=2_b=85_h=15_u04_fe=100_fr=50.in'
experiment_data = load_experiment_conf(sourcing_parameters_path)
total_time = 100
torch.set_default_tensor_type('torch.cuda.FloatTensor')

# %%
sourcing_parameters = dict(ce=int(experiment_data.c_e),
                           cr=int(experiment_data.c_r),
                           le=int(experiment_data.l_e),
                           lr=int(experiment_data.l_r),
                           h=int(experiment_data.h),
                           b=int(experiment_data.b),
                           T=total_time,
                           fe = int(experiment_data.f_e),
                           fr = int(experiment_data.f_r)

                          )
sourcing_parameters = dict(ce=5,
                           cr=0,
                           le=0,
                           lr=2,
                           h=5,
                           b=95,
                           T=100,
                           fe=100,
                           fr=50
                          
                          
                          )

# %%
sourcing_parameters
# Out:
# {'ce': 5,
#  'cr': 0,
#  'le': 0,
#  'lr': 2,
#  'h': 5,
#  'b': 95,
#  'T': 100,
#  'fe': 100,
#  'fr': 50}

# %% [markdown]
# ## NNC Initialization
# Here we initialize an NNC model and set  its hyperparameters for training.

# %%
### One can experiment with different layer architectures and activations per layer
nnc_hyperparameters = dict(
    n_hidden_units = [64, 32, 16, 8]
)

### We use celu non-linearities for the input layer, hidden layers, and output layer
nnc_hyperparameters['n_activations'] = [torch.nn.CELU(alpha=1)]*(2 + len(nnc_hyperparameters['n_hidden_units']))


fcc = FCController(lr=sourcing_parameters['lr'], 
                                         le=sourcing_parameters['le'], 
                                         n_hidden_units= nnc_hyperparameters ['n_hidden_units'],
                                         activations=nnc_hyperparameters['n_activations']
                                        ) # controller neural network object

# %% [markdown]
# ## Dynamics Initialization
# To further optimize NNC (''fine tuning''), we now apply gradient propagation to the inventory evolution equation:
#
# $I_t = I_{t-1} + q^{\rm e}_{t-l_{\rm e}} + q^{\rm r}_{t-l_{\rm r}} - D_t$
#
# where $I_0, q^{\rm e}_{t},q^{\rm r}_{t}$ are NNC outputs.

# %%
dsd = SequentialDualSourcing(fcc, I_0=6, **sourcing_parameters) # Dual Sourcing Dynamics object

# %% [markdown]
# We preserve the best performing model in training, assuming that the neural network generalizes well during training and that our training sample is large enough.

# %%
best_loss = [np.infty]
best_model = [None]

# %%
all_training_costs = []

# %% [markdown]
# We observe that we have a neural network that outputs $q^{\rm r}_{t-l_{\rm r}}, q^{\rm e}_{t-l_{\rm e}}$ given the input described above.
# The initial inventory $I_0$ is independent of inputs and can be learned separately (in a way that is similar to learning a bias term of a neural network).
# We use separate optimizers to learn order quantities and initial inventory.
# This may create learning variance, as one optimizer may overfit on a value that is directly changed by another optimizer.
# To reduce the learning variance, we let the order optimizer operate on 7 out of 10 learning epochs and the inventory optimizer on the remaining epochs.

# %%
optimizer = torch.optim.RMSprop(#[dsd.I_0],
                                list(fcc.parameters()), 
                                lr=3*1e-5
                               )
optimizer2 = torch.optim.RMSprop([dsd.I_0],
                                #list(fcc.parameters()), 
                                lr=1e-5
                               )

# %% [markdown]
# We now fine tune the model after imitation, in order to generalize and hopefully outperform the method used to train the model.
# To do so, we repetively train and fine tune the parameters of 128 trajectories generated by setting a specific random seed. We do not resample new trajectories, as we want the network to overfit on the process. Sampling new samples could increase the input variance, and could potentially slow/prohibit convergence.

# %%
fine_tuning_iterations = 3000
minibatch_size = 256
random_seed = 4

t0 = time.time()
for it in range(fine_tuning_iterations):
    optimizer.zero_grad()
    optimizer2.zero_grad()
    def closure():
        dsd.reset(minibatch_size, seed=random_seed+1)
        total_costs = 0
        for i in range(dsd.T):
            current_costs, demands, current_inventories, qr, qra, qe, qea, nn_context = dsd.simulate()
            total_costs = current_costs.mean() + total_costs
        all_training_costs.append(float(total_costs)/dsd.T)
        total_costs.backward()
        if it % 20 == 0:
            print(total_costs/dsd.T)
        if total_costs < best_loss[0]:
            best_loss[0] = total_costs.detach().cpu().item()
            best_model[0] = deepcopy(fcc.state_dict())
        return total_costs
    #if it > 1 and all_training_costs[-1] <= 26.4:
    #        break
    if it % 10 > 6:
        optimizer2.step(closure)
    else:
        optimizer.step(closure)
t1 = time.time()
total = t1-t0
print(total)
# Out:
# tensor(6518.1880, grad_fn=<DivBackward0>)
# tensor(5270.9937, grad_fn=<DivBackward0>)
# tensor(4769.2148, grad_fn=<DivBackward0>)
# tensor(4366.7910, grad_fn=<DivBackward0>)
# tensor(4047.1514, grad_fn=<DivBackward0>)
# tensor(3792.5554, grad_fn=<DivBackward0>)
# tensor(3603.2737, grad_fn=<DivBackward0>)
# tensor(3400.3723, grad_fn=<DivBackward0>)
# tensor(3200.3560, grad_fn=<DivBackward0>)
# tensor(3049.7844, grad_fn=<DivBackward0>)
# tensor(2919.8672, grad_fn=<DivBackward0>)
# tensor(2823.5669, grad_fn=<DivBackward0>)
# tensor(2684.6411, grad_fn=<DivBackward0>)
# tensor(2603.4277, grad_fn=<DivBackward0>)
# tensor(2467.3167, grad_fn=<DivBackward0>)
# tensor(2385.0876, grad_fn=<DivBackward0>)
# tensor(2321.4915, grad_fn=<DivBackward0>)
# tensor(2243.2446, grad_fn=<DivBackward0>)
# tensor(2159.7559, grad_fn=<DivBackward0>)
# tensor(2079.4990, grad_fn=<DivBackward0>)
# tensor(2013.4187, grad_fn=<DivBackward0>)
# tensor(1930.1487, grad_fn=<DivBackward0>)
# tensor(1849.9760, grad_fn=<DivBackward0>)
# tensor(1780.9928, grad_fn=<DivBackward0>)
# tensor(1696.2837, grad_fn=<DivBackward0>)
# tensor(1694.5046, grad_fn=<DivBackward0>)
# tensor(1611.9377, grad_fn=<DivBackward0>)
# tensor(1541.4698, grad_fn=<DivBackward0>)
# tensor(1457.7120, grad_fn=<DivBackward0>)
# tensor(1454.7012, grad_fn=<DivBackward0>)
# tensor(1370.9188, grad_fn=<DivBackward0>)
# tensor(1367.8859, grad_fn=<DivBackward0>)
# tensor(1295.6057, grad_fn=<DivBackward0>)
# tensor(1209.4062, grad_fn=<DivBackward0>)
# tensor(1209.4062, grad_fn=<DivBackward0>)
# tensor(1205.1462, grad_fn=<DivBackward0>)
# tensor(1134.1266, grad_fn=<DivBackward0>)
# tensor(1119.1506, grad_fn=<DivBackward0>)
# tensor(1047.6223, grad_fn=<DivBackward0>)
# tensor(1046.0133, grad_fn=<DivBackward0>)
# tensor(975.6084, grad_fn=<DivBackward0>)
# tensor(959.1454, grad_fn=<DivBackward0>)
# tensor(951.9622, grad_fn=<DivBackward0>)
# tensor(888.1393, grad_fn=<DivBackward0>)
# tensor(880.6887, grad_fn=<DivBackward0>)
# tensor(880.6887, grad_fn=<DivBackward0>)
# tensor(792.8263, grad_fn=<DivBackward0>)
# tensor(792.8263, grad_fn=<DivBackward0>)
# tensor(782.2796, grad_fn=<DivBackward0>)
# tensor(782.2796, grad_fn=<DivBackward0>)
# tensor(722.7581, grad_fn=<DivBackward0>)
# tensor(712.0517, grad_fn=<DivBackward0>)
# tensor(712.0517, grad_fn=<DivBackward0>)
# tensor(696.1885, grad_fn=<DivBackward0>)
# tensor(625.4150, grad_fn=<DivBackward0>)
# tensor(625.4150, grad_fn=<DivBackward0>)
# tensor(621.8695, grad_fn=<DivBackward0>)
# tensor(606.8623, grad_fn=<DivBackward0>)
# tensor(606.8623, grad_fn=<DivBackward0>)
# tensor(556.7410, grad_fn=<DivBackward0>)
# tensor(556.7076, grad_fn=<DivBackward0>)
# tensor(541.5189, grad_fn=<DivBackward0>)
# tensor(541.5189, grad_fn=<DivBackward0>)
# tensor(541.4855, grad_fn=<DivBackward0>)
# tensor(541.4855, grad_fn=<DivBackward0>)
# tensor(454.4799, grad_fn=<DivBackward0>)
# tensor(454.4465, grad_fn=<DivBackward0>)
# tensor(454.4465, grad_fn=<DivBackward0>)
# tensor(454.4465, grad_fn=<DivBackward0>)
# tensor(454.4465, grad_fn=<DivBackward0>)
# tensor(432.7603, grad_fn=<DivBackward0>)
# tensor(432.7603, grad_fn=<DivBackward0>)
# tensor(432.7603, grad_fn=<DivBackward0>)
# tensor(432.7603, grad_fn=<DivBackward0>)
# tensor(398.0740, grad_fn=<DivBackward0>)
# tensor(373.7662, grad_fn=<DivBackward0>)
# tensor(373.7662, grad_fn=<DivBackward0>)
# tensor(373.7662, grad_fn=<DivBackward0>)
# tensor(373.7662, grad_fn=<DivBackward0>)
# tensor(372.8940, grad_fn=<DivBackward0>)
# tensor(372.8940, grad_fn=<DivBackward0>)
# tensor(372.8940, grad_fn=<DivBackward0>)
# tensor(372.8940, grad_fn=<DivBackward0>)
# tensor(344.1236, grad_fn=<DivBackward0>)
# tensor(342.1297, grad_fn=<DivBackward0>)
# tensor(342.1297, grad_fn=<DivBackward0>)
# tensor(342.1297, grad_fn=<DivBackward0>)
# tensor(317.9455, grad_fn=<DivBackward0>)
# tensor(292.5707, grad_fn=<DivBackward0>)
# tensor(292.5707, grad_fn=<DivBackward0>)
# tensor(284.5457, grad_fn=<DivBackward0>)
# tensor(284.5457, grad_fn=<DivBackward0>)
# tensor(284.5457, grad_fn=<DivBackward0>)
# tensor(262.0361, grad_fn=<DivBackward0>)
# tensor(262.0361, grad_fn=<DivBackward0>)
# tensor(262.0361, grad_fn=<DivBackward0>)
# tensor(262.0361, grad_fn=<DivBackward0>)
# tensor(262.0361, grad_fn=<DivBackward0>)
# tensor(262.0361, grad_fn=<DivBackward0>)
# tensor(248.7672, grad_fn=<DivBackward0>)
# tensor(248.7672, grad_fn=<DivBackward0>)
# tensor(248.7672, grad_fn=<DivBackward0>)
# tensor(248.7672, grad_fn=<DivBackward0>)
# tensor(248.7672, grad_fn=<DivBackward0>)
# tensor(246.9842, grad_fn=<DivBackward0>)
# tensor(246.9842, grad_fn=<DivBackward0>)
# tensor(246.9842, grad_fn=<DivBackward0>)
# tensor(246.9842, grad_fn=<DivBackward0>)
# tensor(229.7154, grad_fn=<DivBackward0>)
# tensor(215.4209, grad_fn=<DivBackward0>)
# tensor(215.4209, grad_fn=<DivBackward0>)
# tensor(215.4209, grad_fn=<DivBackward0>)
# tensor(195.9121, grad_fn=<DivBackward0>)
# tensor(195.9121, grad_fn=<DivBackward0>)
# tensor(195.9121, grad_fn=<DivBackward0>)
# tensor(195.9121, grad_fn=<DivBackward0>)
# tensor(195.9121, grad_fn=<DivBackward0>)
# tensor(195.9121, grad_fn=<DivBackward0>)
# tensor(195.9121, grad_fn=<DivBackward0>)
# tensor(195.9121, grad_fn=<DivBackward0>)
# tensor(195.9121, grad_fn=<DivBackward0>)
# tensor(195.9121, grad_fn=<DivBackward0>)
# tensor(187.1592, grad_fn=<DivBackward0>)
# tensor(174.5350, grad_fn=<DivBackward0>)
# tensor(174.4471, grad_fn=<DivBackward0>)
# tensor(174.3846, grad_fn=<DivBackward0>)
# tensor(174.3846, grad_fn=<DivBackward0>)
# tensor(173.4088, grad_fn=<DivBackward0>)
# tensor(172.8928, grad_fn=<DivBackward0>)
# tensor(172.8127, grad_fn=<DivBackward0>)
# tensor(172.8127, grad_fn=<DivBackward0>)
# tensor(172.8127, grad_fn=<DivBackward0>)
# tensor(162.2541, grad_fn=<DivBackward0>)
# tensor(158.4037, grad_fn=<DivBackward0>)
# tensor(154.4893, grad_fn=<DivBackward0>)
# tensor(154.4893, grad_fn=<DivBackward0>)
# tensor(151.3941, grad_fn=<DivBackward0>)
# tensor(151.3941, grad_fn=<DivBackward0>)
# tensor(151.3941, grad_fn=<DivBackward0>)
# tensor(151.3941, grad_fn=<DivBackward0>)
# tensor(151.3941, grad_fn=<DivBackward0>)
# tensor(151.3941, grad_fn=<DivBackward0>)
# tensor(151.3941, grad_fn=<DivBackward0>)
# tensor(151.3941, grad_fn=<DivBackward0>)
# tensor(148.0713, grad_fn=<DivBackward0>)
# tensor(139.1217, grad_fn=<DivBackward0>)
# tensor(139.1217, grad_fn=<DivBackward0>)
# tensor(139.1217, grad_fn=<DivBackward0>)
# tensor(139.1217, grad_fn=<DivBackward0>)
# tensor(130.5416, grad_fn=<DivBackward0>)
# 922.9187428951263

# %%
dsd.all_demands[0]
# Out:
# tensor([[0.],
#         [4.],
#         [1.],
#         [5.],
#         [4.],
#         [5.],
#         [1.],
#         [1.],
#         [4.],
#         [0.],
#         [5.],
#         [3.],
#         [3.],
#         [0.],
#         [3.],
#         [4.],
#         [3.],
#         [5.],
#         [3.],
#         [0.],
#         [5.],
#         [3.],
#         [1.],
#         [0.],
#         [4.],
#         [5.],
#         [0.],
#         [3.],
#         [3.],
#         [1.],
#         [2.],
#         [1.],
#         [1.],
#         [0.],
#         [2.],
#         [4.],
#         [4.],
#         [5.],
#         [0.],
#         [2.],
#         [5.],
#         [3.],
#         [2.],
#         [0.],
#         [4.],
#         [4.],
#         [5.],
#         [5.],
#         [3.],
#         [4.],
#         [2.],
#         [5.],
#         [2.],
#         [2.],
#         [1.],
#         [4.],
#         [4.],
#         [4.],
#         [1.],
#         [1.],
#         [5.],
#         [1.],
#         [1.],
#         [2.],
#         [2.],
#         [1.],
#         [5.],
#         [3.],
#         [4.],
#         [4.],
#         [1.],
#         [4.],
#         [1.],
#         [2.],
#         [4.],
#         [5.],
#         [5.],
#         [4.],
#         [5.],
#         [2.],
#         [2.],
#         [2.],
#         [2.],
#         [2.],
#         [4.],
#         [4.],
#         [1.],
#         [1.],
#         [2.],
#         [3.],
#         [2.],
#         [1.],
#         [2.],
#         [1.],
#         [3.],
#         [1.],
#         [2.],
#         [2.],
#         [2.],
#         [4.],
#         [4.]])

# %%
best_loss[0]/dsd.T
# Out:
# 130.1025390625

# %%
sourcing_parameters
# Out:
# {'ce': 5,
#  'cr': 0,
#  'le': 0,
#  'lr': 2,
#  'h': 5,
#  'b': 95,
#  'T': 100,
#  'fe': 100,
#  'fr': 50}

# %% [markdown]
# train one nn for lr=2,3,4
#
# Takes several thousand epochs to train one initial NN nicely, then finetuning brings it 1-5% closer to DP
# Fewer epochs for fine-tuning
#
#
# transfer learn for new parameters except lr

# %% [markdown]
# lower lr and increase learning rate close to dp and then increase again.
#
# Start from 10^-3 learning rate
# minibatch size: 256 - 1024 work relative well.
# for lr > 2 use T=150, 200, longer lrs need bigger lrs
#
# Nice initial inventory level, too small and too large initial inventories may bias trainning.
# Between 4 and 8 seems to work very well.

# %%
fine_tuning_iterations = 3000
minibatch_size = 256
random_seed = 9
t0 = time.time()
for it in range(fine_tuning_iterations):
    optimizer.zero_grad()
    optimizer2.zero_grad()
    def closure():
        dsd.reset(minibatch_size, seed=random_seed+1)
        nn_context = {}
        total_costs = 0
        for i in range(dsd.T):
            current_costs, demands, current_inventories, qr, qra, qe, qea, nn_context =\
                dsd.simulate(controller_kwargs=nn_context)
            total_costs = current_costs.mean() + total_costs
        all_training_costs.append(float(total_costs)/dsd.T)
        total_costs.backward()
        if it % 20 == 0:
            print(total_costs/dsd.T)
        if total_costs < best_loss[0]:
            best_loss[0] = total_costs.detach().cpu().item()
            best_model[0] = deepcopy(fcc.state_dict())
        return total_costs
    #if it > 1 and all_training_costs[-1] <= 26.4:
    #        break
    if it % 10 > 6:
        optimizer2.step(closure)
    else:
        optimizer.step(closure)
t1 = time.time()
total = t1-t0
print(total)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-d5f9f870605c> in <module>
#      27         optimizer2.step(closure)
#      28     else:
# ---> 29         optimizer.step(closure)
#      30 t1 = time.time()
#      31 total = t1-t0
#
# ~/miniconda3/envs/numdyn/lib/python3.8/site-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#      86                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#      87                 with torch.autograd.profiler.record_function(profile_name):
# ---> 88                     return func(*args, **kwargs)
#      89             return wrapper
#      90
#
# ~/miniconda3/envs/numdyn/lib/python3.8/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      26         def decorate_context(*args, **kwargs):
#      27             with self.__class__():
# ---> 28                 return func(*args, **kwargs)
#      29         return cast(F, decorate_context)
#      30
#
# ~/miniconda3/envs/numdyn/lib/python3.8/site-packages/torch/optim/rmsprop.py in step(self, closure)
#      94         if closure is not None:
#      95             with torch.enable_grad():
# ---> 96                 loss = closure()
#      97
#      98         for group in self.param_groups:
#
# <ipython-input-14-d5f9f870605c> in closure()
#      12         for i in range(dsd.T):
#      13             current_costs, demands, current_inventories, qr, qra, qe, qea, nn_context =\
# ---> 14                 dsd.simulate(controller_kwargs=nn_context)
#      15             total_costs = current_costs.mean() + total_costs
#      16         all_training_costs.append(float(total_costs)/dsd.T)
#
# ~/repos/inventory-optimization/neural_control/experiments/../../neural_control/extended_dynamics.py in simulate(self, controller_kwargs)
#      58
#      59         # orders that are just placed.
# ---> 60         qr, qe, nn_context = self.controller(past_demands, past_inventories, previous_qr, previous_qe, past_costs, **controller_kwargs)
#      61
#      62         # orders are persisted to respective tensors
#
# TypeError: FCController object argument after ** must be a mapping, not NoneType
