# %% [markdown]
# Contributors: Thomas Asikis, Lucas Bottcher
# ## Imports

# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('../../')
import torch
from neural_control.extended_controllers import LSTMController
from neural_control.extended_dynamics import SequentialDualSourcing
import plotly.express as px
import numpy as np
import matplotlib.pyplot as plt
from copy import deepcopy
from plotly import graph_objects as go
from sourcing_models.utilities import sample_trajectories_capped_dual_index, \
sample_trajectories_dual_index, sample_trajectories_single_index, sample_trajectories_tailored_base_surge
import time


from neural_control.experiments.helpers import load_experiment_conf

import matplotlib.pyplot as plt
from matplotlib import rcParams
#import seaborn as sns

# customized settings
params = {  # 'backend': 'ps',
    'font.family': 'serif',
    'font.serif': 'Latin Modern Roman',
    'font.size': 10,
    'axes.labelsize': 'medium',
    'axes.titlesize': 'medium',
    'legend.fontsize': 'medium',
    'xtick.labelsize': 'small',
    'ytick.labelsize': 'small',
    'savefig.dpi': 150,
    'text.usetex': True}
# tell matplotlib about your params
rcParams.update(params)

# %% [markdown]
# ## Sourcing Problem Parameters

# %%
sourcing_parameters_path = '../../sourcing_models/recursion_input_files/low_service_fc1_lr=2_b=85_h=15_u04_fe=100_fr=50.in'
experiment_data = load_experiment_conf(sourcing_parameters_path)
total_time = 100
torch.set_default_tensor_type('torch.cuda.FloatTensor')

# %%
sourcing_parameters = dict(ce=int(experiment_data.c_e),
                           cr=int(experiment_data.c_r),
                           le=int(experiment_data.l_e),
                           lr=int(experiment_data.l_r),
                           h=int(experiment_data.h),
                           b=int(experiment_data.b),
                           T=total_time,
                           fe = int(experiment_data.f_e),
                           fr = int(experiment_data.f_r)

                          )

# %%
sourcing_parameters
# Out:
# {'ce': 5,
#  'cr': 0,
#  'le': 0,
#  'lr': 2,
#  'h': 15,
#  'b': 85,
#  'T': 100,
#  'fe': 100,
#  'fr': 50}

# %% [markdown]
# ## NNC Initialization
# Here we initialize an NNC model and set  its hyperparameters for training.

# %%
### One can experiment with different layer architectures and activations per layer
nnc_hyperparameters = dict(
    n_hidden_units = [64, 32, 16, 8]
)

### We use celu non-linearities for the input layer, hidden layers, and output layer
nnc_hyperparameters['n_activations'] = [torch.nn.CELU(alpha=1)]*(2 + len(nnc_hyperparameters['n_hidden_units']))


fcc = LSTMController(lr=sourcing_parameters['lr'], 
                                         le=sourcing_parameters['le'], 
                                          hidden_size=32,
                                          num_layers=1,
                                        ) # controller neural network object

# %% [markdown]
# ## Dynamics Initialization
# To further optimize NNC (''fine tuning''), we now apply gradient propagation to the inventory evolution equation:
#
# $I_t = I_{t-1} + q^{\rm e}_{t-l_{\rm e}} + q^{\rm r}_{t-l_{\rm r}} - D_t$
#
# where $I_0, q^{\rm e}_{t},q^{\rm r}_{t}$ are NNC outputs.

# %%
dsd = SequentialDualSourcing(fcc, I_0=6, **sourcing_parameters) # Dual Sourcing Dynamics object

# %% [markdown]
# We preserve the best performing model in training, assuming that the neural network generalizes well during training and that our training sample is large enough.

# %%
best_loss = [np.infty]
best_model = [None]

# %%
all_training_costs = []

# %% [markdown]
# We observe that we have a neural network that outputs $q^{\rm r}_{t-l_{\rm r}}, q^{\rm e}_{t-l_{\rm e}}$ given the input described above.
# The initial inventory $I_0$ is independent of inputs and can be learned separately (in a way that is similar to learning a bias term of a neural network).
# We use separate optimizers to learn order quantities and initial inventory.
# This may create learning variance, as one optimizer may overfit on a value that is directly changed by another optimizer.
# To reduce the learning variance, we let the order optimizer operate on 7 out of 10 learning epochs and the inventory optimizer on the remaining epochs.

# %%
optimizer = torch.optim.RMSprop(#[dsd.I_0],
                                list(fcc.parameters()), 
                                lr=3*1e-3
                               )
optimizer2 = torch.optim.RMSprop([dsd.I_0],
                                #list(fcc.parameters()), 
                                lr=1e-3
                               )

# %% [markdown]
# We now fine tune the model after imitation, in order to generalize and hopefully outperform the method used to train the model.
# To do so, we repetively train and fine tune the parameters of 128 trajectories generated by setting a specific random seed. We do not resample new trajectories, as we want the network to overfit on the process. Sampling new samples could increase the input variance, and could potentially slow/prohibit convergence.

# %%
fine_tuning_iterations = 3000
minibatch_size = 256
random_seed = 5

t0 = time.time()
for it in range(fine_tuning_iterations):
    optimizer.zero_grad()
    optimizer2.zero_grad()
    def closure():
        dsd.reset(minibatch_size, seed=random_seed+1)
        nn_context = {}
        total_costs = 0
        for i in range(dsd.T):
            current_costs, demands, current_inventories, qr, qra, qe, qea, nn_context = dsd.simulate(nn_context)
            total_costs = current_costs.mean() + total_costs
        all_training_costs.append(float(total_costs)/dsd.T)
        total_costs.backward()
        if it % 20 == 0:
            print(total_costs/dsd.T)
        if total_costs < best_loss[0]:
            best_loss[0] = total_costs.detach().cpu().item()
            best_model[0] = deepcopy(fcc.state_dict())
        return total_costs
    #if it > 1 and all_training_costs[-1] <= 26.4:
    #        break
    if it % 10 > 6:
        optimizer2.step(closure)
    else:
        optimizer.step(closure)
t1 = time.time()
total = t1-t0
print(total)
# Out:
# tensor(109.7514, grad_fn=<DivBackward0>)
# tensor(106.9012, grad_fn=<DivBackward0>)
# tensor(111.1473, grad_fn=<DivBackward0>)
# tensor(108.0664, grad_fn=<DivBackward0>)
# tensor(109.2574, grad_fn=<DivBackward0>)
# tensor(107.7314, grad_fn=<DivBackward0>)
# tensor(106.6416, grad_fn=<DivBackward0>)
# tensor(106.5006, grad_fn=<DivBackward0>)
# tensor(109.8113, grad_fn=<DivBackward0>)
# tensor(106.9836, grad_fn=<DivBackward0>)
# tensor(108.8883, grad_fn=<DivBackward0>)
# tensor(107.7379, grad_fn=<DivBackward0>)
# tensor(106.6797, grad_fn=<DivBackward0>)
# tensor(106.5014, grad_fn=<DivBackward0>)
# tensor(106.5426, grad_fn=<DivBackward0>)
# tensor(106.6900, grad_fn=<DivBackward0>)
# tensor(106.8961, grad_fn=<DivBackward0>)
# tensor(108.7764, grad_fn=<DivBackward0>)
# tensor(106.7648, grad_fn=<DivBackward0>)
# tensor(109.5768, grad_fn=<DivBackward0>)
# tensor(106.4127, grad_fn=<DivBackward0>)
# tensor(106.4762, grad_fn=<DivBackward0>)
# tensor(106.6699, grad_fn=<DivBackward0>)
# tensor(109.2033, grad_fn=<DivBackward0>)
# tensor(108.4346, grad_fn=<DivBackward0>)
# tensor(107.7310, grad_fn=<DivBackward0>)
# tensor(106.7174, grad_fn=<DivBackward0>)
# tensor(106.5004, grad_fn=<DivBackward0>)
# tensor(106.6709, grad_fn=<DivBackward0>)
# tensor(106.5109, grad_fn=<DivBackward0>)
# tensor(106.4799, grad_fn=<DivBackward0>)
# tensor(106.5535, grad_fn=<DivBackward0>)
# tensor(106.7020, grad_fn=<DivBackward0>)
# tensor(106.7811, grad_fn=<DivBackward0>)
# tensor(106.4756, grad_fn=<DivBackward0>)
# tensor(106.4494, grad_fn=<DivBackward0>)
# tensor(106.6654, grad_fn=<DivBackward0>)
# tensor(107.1141, grad_fn=<DivBackward0>)
# tensor(108.2246, grad_fn=<DivBackward0>)
# tensor(108.8396, grad_fn=<DivBackward0>)
# tensor(108.4559, grad_fn=<DivBackward0>)
# tensor(108.3295, grad_fn=<DivBackward0>)
# tensor(108.8482, grad_fn=<DivBackward0>)
# tensor(108.2525, grad_fn=<DivBackward0>)
# tensor(108.6750, grad_fn=<DivBackward0>)
# tensor(108.7350, grad_fn=<DivBackward0>)
# tensor(107.4328, grad_fn=<DivBackward0>)
# tensor(108.7621, grad_fn=<DivBackward0>)
# tensor(108.0920, grad_fn=<DivBackward0>)
# tensor(107.9957, grad_fn=<DivBackward0>)
# tensor(107.9953, grad_fn=<DivBackward0>)
# tensor(106.7416, grad_fn=<DivBackward0>)
# tensor(106.4965, grad_fn=<DivBackward0>)
# tensor(106.4521, grad_fn=<DivBackward0>)
# tensor(106.7455, grad_fn=<DivBackward0>)
# tensor(106.1803, grad_fn=<DivBackward0>)
# tensor(107.0227, grad_fn=<DivBackward0>)
# tensor(108.0623, grad_fn=<DivBackward0>)
# tensor(107.9854, grad_fn=<DivBackward0>)
# tensor(107.5676, grad_fn=<DivBackward0>)
# tensor(108.1418, grad_fn=<DivBackward0>)
# tensor(107.7352, grad_fn=<DivBackward0>)
# tensor(107.9904, grad_fn=<DivBackward0>)
# tensor(107.7545, grad_fn=<DivBackward0>)
# tensor(107.5682, grad_fn=<DivBackward0>)
# tensor(107.6033, grad_fn=<DivBackward0>)
# tensor(107.4830, grad_fn=<DivBackward0>)
# tensor(107.3406, grad_fn=<DivBackward0>)
# tensor(106.9455, grad_fn=<DivBackward0>)
# tensor(107.4269, grad_fn=<DivBackward0>)
# tensor(107.5018, grad_fn=<DivBackward0>)
# tensor(107.6801, grad_fn=<DivBackward0>)
# tensor(106.8283, grad_fn=<DivBackward0>)
# tensor(107.5641, grad_fn=<DivBackward0>)
# tensor(107.7340, grad_fn=<DivBackward0>)
# tensor(107.4967, grad_fn=<DivBackward0>)
# tensor(107.6637, grad_fn=<DivBackward0>)
# tensor(106.0529, grad_fn=<DivBackward0>)
# tensor(105.7566, grad_fn=<DivBackward0>)
# tensor(106.4236, grad_fn=<DivBackward0>)
# tensor(106.9561, grad_fn=<DivBackward0>)
# tensor(107.6553, grad_fn=<DivBackward0>)
# tensor(107.4424, grad_fn=<DivBackward0>)
# tensor(107.4568, grad_fn=<DivBackward0>)
# tensor(107.5010, grad_fn=<DivBackward0>)
# tensor(106.1228, grad_fn=<DivBackward0>)
# tensor(106.0889, grad_fn=<DivBackward0>)
# tensor(106.0465, grad_fn=<DivBackward0>)
# tensor(105.8486, grad_fn=<DivBackward0>)
# tensor(106.3967, grad_fn=<DivBackward0>)
# tensor(105.8670, grad_fn=<DivBackward0>)
# tensor(107.1705, grad_fn=<DivBackward0>)
# tensor(105.7602, grad_fn=<DivBackward0>)
# tensor(107.0938, grad_fn=<DivBackward0>)
# tensor(106.0697, grad_fn=<DivBackward0>)
# tensor(105.6297, grad_fn=<DivBackward0>)
# tensor(106.0805, grad_fn=<DivBackward0>)
# tensor(107.0113, grad_fn=<DivBackward0>)
# tensor(106.9754, grad_fn=<DivBackward0>)
# tensor(107.4969, grad_fn=<DivBackward0>)
# tensor(107.1682, grad_fn=<DivBackward0>)
# tensor(107.6359, grad_fn=<DivBackward0>)
# tensor(106.7049, grad_fn=<DivBackward0>)
# tensor(106.1143, grad_fn=<DivBackward0>)
# tensor(105.5391, grad_fn=<DivBackward0>)
# tensor(107.0484, grad_fn=<DivBackward0>)
# tensor(105.8385, grad_fn=<DivBackward0>)
# tensor(105.6068, grad_fn=<DivBackward0>)
# tensor(107.4689, grad_fn=<DivBackward0>)
# tensor(105.7322, grad_fn=<DivBackward0>)
# tensor(105.1555, grad_fn=<DivBackward0>)
# tensor(106.4295, grad_fn=<DivBackward0>)
# tensor(107.0002, grad_fn=<DivBackward0>)
# tensor(105.7850, grad_fn=<DivBackward0>)
# tensor(105.5697, grad_fn=<DivBackward0>)
# tensor(105.9830, grad_fn=<DivBackward0>)
# tensor(105.6502, grad_fn=<DivBackward0>)
# tensor(105.3439, grad_fn=<DivBackward0>)
# tensor(107.4568, grad_fn=<DivBackward0>)
# tensor(107.2988, grad_fn=<DivBackward0>)
# tensor(106.7594, grad_fn=<DivBackward0>)
# tensor(107.2701, grad_fn=<DivBackward0>)
# tensor(105.6451, grad_fn=<DivBackward0>)
# tensor(107.2594, grad_fn=<DivBackward0>)
# tensor(105.9408, grad_fn=<DivBackward0>)
# tensor(106.2945, grad_fn=<DivBackward0>)
# tensor(107.2406, grad_fn=<DivBackward0>)
# tensor(106.6447, grad_fn=<DivBackward0>)
# tensor(106.8736, grad_fn=<DivBackward0>)
# tensor(106.8184, grad_fn=<DivBackward0>)
# tensor(105.4896, grad_fn=<DivBackward0>)
# tensor(105.6719, grad_fn=<DivBackward0>)
# tensor(105.4174, grad_fn=<DivBackward0>)
# tensor(105.4701, grad_fn=<DivBackward0>)
# tensor(105.1693, grad_fn=<DivBackward0>)
# tensor(105.3977, grad_fn=<DivBackward0>)
# tensor(106.0201, grad_fn=<DivBackward0>)
# tensor(105.7537, grad_fn=<DivBackward0>)
# tensor(104.9062, grad_fn=<DivBackward0>)
# tensor(105.1629, grad_fn=<DivBackward0>)
# tensor(105.4141, grad_fn=<DivBackward0>)
# tensor(104.9143, grad_fn=<DivBackward0>)
# tensor(108.1625, grad_fn=<DivBackward0>)
# tensor(105.9717, grad_fn=<DivBackward0>)
# tensor(105.8754, grad_fn=<DivBackward0>)
# tensor(105.0330, grad_fn=<DivBackward0>)
# tensor(105.9311, grad_fn=<DivBackward0>)
# tensor(105.2740, grad_fn=<DivBackward0>)
# tensor(105.1133, grad_fn=<DivBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-22460a3d33ab> in <module>
#      25     #        break
#      26     if it % 10 > 6:
# ---> 27         optimizer2.step(closure)
#      28     else:
#      29         optimizer.step(closure)
#
# ~/miniconda3/envs/numdyn/lib/python3.8/site-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#      86                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#      87                 with torch.autograd.profiler.record_function(profile_name):
# ---> 88                     return func(*args, **kwargs)
#      89             return wrapper
#      90
#
# ~/miniconda3/envs/numdyn/lib/python3.8/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      26         def decorate_context(*args, **kwargs):
#      27             with self.__class__():
# ---> 28                 return func(*args, **kwargs)
#      29         return cast(F, decorate_context)
#      30
#
# ~/miniconda3/envs/numdyn/lib/python3.8/site-packages/torch/optim/rmsprop.py in step(self, closure)
#      94         if closure is not None:
#      95             with torch.enable_grad():
# ---> 96                 loss = closure()
#      97
#      98         for group in self.param_groups:
#
# <ipython-input-21-22460a3d33ab> in closure()
#      15             total_costs = current_costs.mean() + total_costs
#      16         all_training_costs.append(float(total_costs)/dsd.T)
# ---> 17         total_costs.backward()
#      18         if it % 20 == 0:
#      19             print(total_costs/dsd.T)
#
# ~/miniconda3/envs/numdyn/lib/python3.8/site-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     305                 create_graph=create_graph,
#     306                 inputs=inputs)
# --> 307         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     308
#     309     def register_hook(self, hook):
#
# ~/miniconda3/envs/numdyn/lib/python3.8/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     152         retain_graph = create_graph
#     153
# --> 154     Variable._execution_engine.run_backward(
#     155         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     156         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#
# KeyboardInterrupt:

# %%
best_loss[0]/dsd.T
# Out:
# 106.768359375

# %%
sourcing_parameters
# Out:
# {'ce': 5,
#  'cr': 0,
#  'le': 0,
#  'lr': 2,
#  'h': 15,
#  'b': 85,
#  'T': 100,
#  'fe': 100,
#  'fr': 50}

# %% [markdown]
# train one nn for lr=2,3,4
#
# Takes several thousand epochs to train one initial NN nicely, then finetuning brings it 1-5% closer to DP
# Fewer epochs for fine-tuning
#
#
# transfer learn for new parameters except lr

# %% [markdown]
# lower lr and increase learning rate close to dp and then increase again.
#
# Start from 10^-3 learning rate
# minibatch size: 256 - 1024 work relative well.
# for lr > 2 use T=150, 200, longer lrs need bigger lrs
#
# Nice initial inventory level, too small and too large initial inventories may bias trainning.
# Between 4 and 8 seems to work very well.

# %%
fine_tuning_iterations = 3000
minibatch_size = 256
random_seed = 500

t0 = time.time()
dsd.reset(minibatch_size, seed=random_seed+1)
nn_context = {}
total_costs = 0
for i in range(dsd.T):
    current_costs, demands, current_inventories, qr, qra, qe, qea, nn_context = dsd.simulate(nn_context)
    total_costs = current_costs.mean() + total_costs

print(total_costs/dsd.T)

t1 = time.time()
total = t1-t0
print(total)
# Out:
# tensor(108.2828, grad_fn=<DivBackward0>)
# 0.10863447189331055
