# %% [markdown]
# Contributors: Thomas Asikis, Lucas Bottcher
# ## Imports

# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('../../')
import torch
from neural_control.extended_controllers import LSTMController
from neural_control.extended_dynamics import SequentialDualSourcing
import plotly.express as px
import numpy as np
import matplotlib.pyplot as plt
from copy import deepcopy
from plotly import graph_objects as go
from sourcing_models.utilities import sample_trajectories_capped_dual_index, \
sample_trajectories_dual_index, sample_trajectories_single_index, sample_trajectories_tailored_base_surge
import time


from neural_control.experiments.helpers import load_experiment_conf

import matplotlib.pyplot as plt
from matplotlib import rcParams
#import seaborn as sns

# customized settings
params = {  # 'backend': 'ps',
    'font.family': 'serif',
    'font.serif': 'Latin Modern Roman',
    'font.size': 10,
    'axes.labelsize': 'medium',
    'axes.titlesize': 'medium',
    'legend.fontsize': 'medium',
    'xtick.labelsize': 'small',
    'ytick.labelsize': 'small',
    'savefig.dpi': 150,
    'text.usetex': True}
# tell matplotlib about your params
rcParams.update(params)

# %% [markdown]
# ## Sourcing Problem Parameters

# %%
sourcing_parameters_path = '../../sourcing_models/recursion_input_files/low_service_fc1_lr=2_b=85_h=15_u04_fe=100_fr=50.in'
experiment_data = load_experiment_conf(sourcing_parameters_path)
total_time = 100
torch.set_default_tensor_type('torch.cuda.FloatTensor')

# %%
sourcing_parameters = dict(ce=int(experiment_data.c_e),
                           cr=int(experiment_data.c_r),
                           le=int(experiment_data.l_e),
                           lr=int(experiment_data.l_r),
                           h=int(experiment_data.h),
                           b=int(experiment_data.b),
                           T=total_time,
                           fe = int(experiment_data.f_e),
                           fr = int(experiment_data.f_r)

                          )
sourcing_parameters = dict(ce=20,
                           cr=0,
                           le=0,
                           lr=2,
                           h=5,
                           b=495,
                           T=150,
                           fe=100,
                           fr=50
                          )

# %%
sourcing_parameters
# Out:
# {'ce': 5,
#  'cr': 0,
#  'le': 0,
#  'lr': 2,
#  'h': 15,
#  'b': 85,
#  'T': 100,
#  'fe': 100,
#  'fr': 50}

# %% [markdown]
# ## NNC Initialization
# Here we initialize an NNC model and set  its hyperparameters for training.

# %%
### One can experiment with different layer architectures and activations per layer
nnc_hyperparameters = dict(
    n_hidden_units = [64, 32, 16, 8]
)

### We use celu non-linearities for the input layer, hidden layers, and output layer
nnc_hyperparameters['n_activations'] = [torch.nn.CELU(alpha=1)]*(2 + len(nnc_hyperparameters['n_hidden_units']))


fcc = LSTMController(lr=sourcing_parameters['lr'], 
                                         le=sourcing_parameters['le'], 
                                          hidden_size=32,
                                          num_layers=1,
                                        ) # controller neural network object

# %% [markdown]
# ## Dynamics Initialization
# To further optimize NNC (''fine tuning''), we now apply gradient propagation to the inventory evolution equation:
#
# $I_t = I_{t-1} + q^{\rm e}_{t-l_{\rm e}} + q^{\rm r}_{t-l_{\rm r}} - D_t$
#
# where $I_0, q^{\rm e}_{t},q^{\rm r}_{t}$ are NNC outputs.

# %%
dsd = SequentialDualSourcing(fcc, I_0=6, **sourcing_parameters) # Dual Sourcing Dynamics object

# %% [markdown]
# We preserve the best performing model in training, assuming that the neural network generalizes well during training and that our training sample is large enough.

# %%
best_loss = [np.infty]
best_model = [None]

# %%
all_training_costs = []

# %% [markdown]
# We observe that we have a neural network that outputs $q^{\rm r}_{t-l_{\rm r}}, q^{\rm e}_{t-l_{\rm e}}$ given the input described above.
# The initial inventory $I_0$ is independent of inputs and can be learned separately (in a way that is similar to learning a bias term of a neural network).
# We use separate optimizers to learn order quantities and initial inventory.
# This may create learning variance, as one optimizer may overfit on a value that is directly changed by another optimizer.
# To reduce the learning variance, we let the order optimizer operate on 7 out of 10 learning epochs and the inventory optimizer on the remaining epochs.

# %%
optimizer = torch.optim.RMSprop(#[dsd.I_0],
                                list(fcc.parameters()), 
                                lr=3*1e-3
                               )
optimizer2 = torch.optim.RMSprop([dsd.I_0],
                                #list(fcc.parameters()), 
                                lr=1e-3
                               )

# %% [markdown]
# We now fine tune the model after imitation, in order to generalize and hopefully outperform the method used to train the model.
# To do so, we repetively train and fine tune the parameters of 128 trajectories generated by setting a specific random seed. We do not resample new trajectories, as we want the network to overfit on the process. Sampling new samples could increase the input variance, and could potentially slow/prohibit convergence.

# %%
fine_tuning_iterations = 3000
minibatch_size = 256
random_seed = 5

t0 = time.time()
for it in range(fine_tuning_iterations):
    optimizer.zero_grad()
    optimizer2.zero_grad()
    def closure():
        dsd.reset(minibatch_size, seed=random_seed+1)
        nn_context = {}
        total_costs = 0
        for i in range(dsd.T):
            current_costs, demands, current_inventories, qr, qra, qe, qea, nn_context = dsd.simulate(nn_context)
            total_costs = current_costs.mean() + total_costs
        all_training_costs.append(float(total_costs)/dsd.T)
        total_costs.backward()
        if it % 20 == 0:
            print(total_costs/dsd.T)
        if total_costs < best_loss[0]:
            best_loss[0] = total_costs.detach().cpu().item()
            best_model[0] = deepcopy(fcc.state_dict())
        return total_costs
    #if it > 1 and all_training_costs[-1] <= 26.4:
    #        break
    if it % 10 > 6:
        optimizer2.step(closure)
    else:
        optimizer.step(closure)
t1 = time.time()
total = t1-t0
print(total)
# Out:
# tensor(10275.1123, grad_fn=<DivBackward0>)
# tensor(315.4248, grad_fn=<DivBackward0>)
# tensor(190.2307, grad_fn=<DivBackward0>)
# tensor(147.7707, grad_fn=<DivBackward0>)
# tensor(132.1320, grad_fn=<DivBackward0>)
# tensor(131.1611, grad_fn=<DivBackward0>)
# tensor(127.9295, grad_fn=<DivBackward0>)
# tensor(125.5139, grad_fn=<DivBackward0>)
# tensor(125.4018, grad_fn=<DivBackward0>)
# tensor(123.9010, grad_fn=<DivBackward0>)
# tensor(123.0435, grad_fn=<DivBackward0>)
# tensor(121.8502, grad_fn=<DivBackward0>)
# tensor(120.8605, grad_fn=<DivBackward0>)
# tensor(120.1986, grad_fn=<DivBackward0>)
# tensor(119.4727, grad_fn=<DivBackward0>)
# tensor(118.9900, grad_fn=<DivBackward0>)
# tensor(118.0525, grad_fn=<DivBackward0>)
# tensor(117.8025, grad_fn=<DivBackward0>)
# tensor(117.2016, grad_fn=<DivBackward0>)
# tensor(116.8752, grad_fn=<DivBackward0>)
# tensor(116.6807, grad_fn=<DivBackward0>)
# tensor(116.5363, grad_fn=<DivBackward0>)
# tensor(115.4375, grad_fn=<DivBackward0>)
# tensor(115.3957, grad_fn=<DivBackward0>)
# tensor(115.1639, grad_fn=<DivBackward0>)
# tensor(114.9799, grad_fn=<DivBackward0>)
# tensor(114.8406, grad_fn=<DivBackward0>)
# tensor(114.6020, grad_fn=<DivBackward0>)
# tensor(114.2406, grad_fn=<DivBackward0>)
# tensor(114.8559, grad_fn=<DivBackward0>)
# tensor(113.9232, grad_fn=<DivBackward0>)
# tensor(113.5553, grad_fn=<DivBackward0>)
# tensor(113.3246, grad_fn=<DivBackward0>)
# tensor(114.6053, grad_fn=<DivBackward0>)
# tensor(113.5312, grad_fn=<DivBackward0>)
# tensor(113.0967, grad_fn=<DivBackward0>)
# tensor(112.3965, grad_fn=<DivBackward0>)
# tensor(111.9885, grad_fn=<DivBackward0>)
# tensor(111.7848, grad_fn=<DivBackward0>)
# tensor(111.5957, grad_fn=<DivBackward0>)
# tensor(111.3391, grad_fn=<DivBackward0>)
# tensor(111.1965, grad_fn=<DivBackward0>)
# tensor(110.9771, grad_fn=<DivBackward0>)
# tensor(110.7191, grad_fn=<DivBackward0>)
# tensor(110.5066, grad_fn=<DivBackward0>)
# tensor(110.3502, grad_fn=<DivBackward0>)
# tensor(110.0004, grad_fn=<DivBackward0>)
# tensor(109.8312, grad_fn=<DivBackward0>)
# tensor(109.5838, grad_fn=<DivBackward0>)
# tensor(109.4773, grad_fn=<DivBackward0>)
# tensor(109.1143, grad_fn=<DivBackward0>)
# tensor(108.8842, grad_fn=<DivBackward0>)
# tensor(108.6920, grad_fn=<DivBackward0>)
# tensor(108.5059, grad_fn=<DivBackward0>)
# tensor(108.3043, grad_fn=<DivBackward0>)
# tensor(108.1469, grad_fn=<DivBackward0>)
# tensor(107.9582, grad_fn=<DivBackward0>)
# tensor(107.7607, grad_fn=<DivBackward0>)
# tensor(107.7445, grad_fn=<DivBackward0>)
# tensor(107.7689, grad_fn=<DivBackward0>)
# tensor(107.6109, grad_fn=<DivBackward0>)
# tensor(107.5670, grad_fn=<DivBackward0>)
# tensor(107.2881, grad_fn=<DivBackward0>)
# tensor(107.2357, grad_fn=<DivBackward0>)
# tensor(108.6248, grad_fn=<DivBackward0>)
# tensor(107.7689, grad_fn=<DivBackward0>)
# tensor(107.6152, grad_fn=<DivBackward0>)
# tensor(109.5168, grad_fn=<DivBackward0>)
# tensor(107.8836, grad_fn=<DivBackward0>)
# tensor(107.7334, grad_fn=<DivBackward0>)
# tensor(106.9859, grad_fn=<DivBackward0>)
# tensor(107.2383, grad_fn=<DivBackward0>)
# tensor(109.3119, grad_fn=<DivBackward0>)
# tensor(110.2658, grad_fn=<DivBackward0>)
# tensor(108.3297, grad_fn=<DivBackward0>)
# tensor(109.2008, grad_fn=<DivBackward0>)
# tensor(107.3432, grad_fn=<DivBackward0>)
# tensor(107.8719, grad_fn=<DivBackward0>)
# tensor(108.4713, grad_fn=<DivBackward0>)
# tensor(107.3982, grad_fn=<DivBackward0>)
# tensor(108.5164, grad_fn=<DivBackward0>)
# tensor(108.1029, grad_fn=<DivBackward0>)
# tensor(106.9305, grad_fn=<DivBackward0>)
# tensor(108.8439, grad_fn=<DivBackward0>)
# tensor(107.9029, grad_fn=<DivBackward0>)
# tensor(106.5129, grad_fn=<DivBackward0>)
# tensor(107.5984, grad_fn=<DivBackward0>)
# tensor(108.0447, grad_fn=<DivBackward0>)
# tensor(108.0728, grad_fn=<DivBackward0>)
# tensor(108.5514, grad_fn=<DivBackward0>)
# tensor(109.5146, grad_fn=<DivBackward0>)
# tensor(106.8703, grad_fn=<DivBackward0>)
# tensor(106.3506, grad_fn=<DivBackward0>)
# tensor(106.3389, grad_fn=<DivBackward0>)
# tensor(106.6490, grad_fn=<DivBackward0>)
# tensor(107.3912, grad_fn=<DivBackward0>)
# tensor(106.7119, grad_fn=<DivBackward0>)
# tensor(109.3311, grad_fn=<DivBackward0>)
# tensor(106.7850, grad_fn=<DivBackward0>)
# tensor(109.4115, grad_fn=<DivBackward0>)
# tensor(107.6217, grad_fn=<DivBackward0>)
# tensor(107.2973, grad_fn=<DivBackward0>)
# tensor(109.4584, grad_fn=<DivBackward0>)
# tensor(106.5090, grad_fn=<DivBackward0>)
# tensor(106.5164, grad_fn=<DivBackward0>)
# tensor(106.9469, grad_fn=<DivBackward0>)
# tensor(106.4766, grad_fn=<DivBackward0>)
# tensor(106.9133, grad_fn=<DivBackward0>)
# tensor(107.1152, grad_fn=<DivBackward0>)
# tensor(106.6285, grad_fn=<DivBackward0>)
# tensor(106.5371, grad_fn=<DivBackward0>)
# tensor(108.8842, grad_fn=<DivBackward0>)
# tensor(106.9109, grad_fn=<DivBackward0>)
# tensor(106.2699, grad_fn=<DivBackward0>)
# tensor(106.6799, grad_fn=<DivBackward0>)
# tensor(106.2777, grad_fn=<DivBackward0>)
# tensor(106.1803, grad_fn=<DivBackward0>)
# tensor(106.9369, grad_fn=<DivBackward0>)
# tensor(106.8967, grad_fn=<DivBackward0>)
# tensor(106.0953, grad_fn=<DivBackward0>)
# tensor(107.5463, grad_fn=<DivBackward0>)
# tensor(107.6039, grad_fn=<DivBackward0>)
# tensor(107.2734, grad_fn=<DivBackward0>)
# tensor(108.1195, grad_fn=<DivBackward0>)
# tensor(107.7623, grad_fn=<DivBackward0>)
# tensor(107.6437, grad_fn=<DivBackward0>)
# tensor(106.1312, grad_fn=<DivBackward0>)
# tensor(106.3521, grad_fn=<DivBackward0>)
# tensor(107.4711, grad_fn=<DivBackward0>)
# tensor(106.0643, grad_fn=<DivBackward0>)
# tensor(107.8795, grad_fn=<DivBackward0>)
# tensor(106.7334, grad_fn=<DivBackward0>)
# tensor(106.2781, grad_fn=<DivBackward0>)
# tensor(108.2935, grad_fn=<DivBackward0>)
# tensor(106.5607, grad_fn=<DivBackward0>)
# tensor(106.6197, grad_fn=<DivBackward0>)
# tensor(106.1768, grad_fn=<DivBackward0>)
# tensor(106.0516, grad_fn=<DivBackward0>)
# tensor(106.4019, grad_fn=<DivBackward0>)
# tensor(106.4234, grad_fn=<DivBackward0>)
# tensor(106.2498, grad_fn=<DivBackward0>)
# tensor(106.4080, grad_fn=<DivBackward0>)
# tensor(106.2941, grad_fn=<DivBackward0>)
# tensor(106.7127, grad_fn=<DivBackward0>)
# tensor(106.1537, grad_fn=<DivBackward0>)
# tensor(106.2441, grad_fn=<DivBackward0>)
# tensor(106.3113, grad_fn=<DivBackward0>)
# tensor(106.8494, grad_fn=<DivBackward0>)
# tensor(106.5332, grad_fn=<DivBackward0>)
# tensor(106.1260, grad_fn=<DivBackward0>)
# 754.2277686595917

# %%
best_loss[0]/dsd.T
# Out:
# 106.768359375

# %%
sourcing_parameters
# Out:
# {'ce': 5,
#  'cr': 0,
#  'le': 0,
#  'lr': 2,
#  'h': 15,
#  'b': 85,
#  'T': 100,
#  'fe': 100,
#  'fr': 50}

# %% [markdown]
# train one nn for lr=2,3,4
#
# Takes several thousand epochs to train one initial NN nicely, then finetuning brings it 1-5% closer to DP
# Fewer epochs for fine-tuning
#
#
# transfer learn for new parameters except lr

# %% [markdown]
# lower lr and increase learning rate close to dp and then increase again.
#
# Start from 10^-3 learning rate
# minibatch size: 256 - 1024 work relative well.
# for lr > 2 use T=150, 200, longer lrs need bigger lrs
#
# Nice initial inventory level, too small and too large initial inventories may bias trainning.
# Between 4 and 8 seems to work very well.

# %%
fine_tuning_iterations = 3000
minibatch_size = 256
random_seed = 500

t0 = time.time()
dsd.reset(minibatch_size, seed=random_seed+1)
nn_context = {}
total_costs = 0
for i in range(dsd.T):
    current_costs, demands, current_inventories, qr, qra, qe, qea, nn_context = dsd.simulate(nn_context)
    total_costs = current_costs.mean() + total_costs

print(total_costs/dsd.T)

t1 = time.time()
total = t1-t0
print(total)
# Out:
# tensor(108.2828, grad_fn=<DivBackward0>)
# 0.10863447189331055
