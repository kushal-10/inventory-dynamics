# %% [markdown]
# Contributors: Thomas Asikis, Lucas Bottcher
# ## Imports

# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('../../')
import torch
from neural_control.extended_controllers import LSTMController
from neural_control.extended_dynamics import SequentialDualSourcing
import plotly.express as px
import numpy as np
import matplotlib.pyplot as plt
from copy import deepcopy
from plotly import graph_objects as go
from sourcing_models.utilities import sample_trajectories_capped_dual_index, \
sample_trajectories_dual_index, sample_trajectories_single_index, sample_trajectories_tailored_base_surge
import time


from neural_control.experiments.helpers import load_experiment_conf

import matplotlib.pyplot as plt
from matplotlib import rcParams
#import seaborn as sns

# customized settings
params = {  # 'backend': 'ps',
    'font.family': 'serif',
    'font.serif': 'Latin Modern Roman',
    'font.size': 10,
    'axes.labelsize': 'medium',
    'axes.titlesize': 'medium',
    'legend.fontsize': 'medium',
    'xtick.labelsize': 'small',
    'ytick.labelsize': 'small',
    'savefig.dpi': 150,
    'text.usetex': True}
# tell matplotlib about your params
rcParams.update(params)

# %% [markdown]
# ## Sourcing Problem Parameters

# %%
sourcing_parameters_path = '../../sourcing_models/recursion_input_files/low_service_fc1_lr=2_b=85_h=15_u04_fe=100_fr=50.in'
experiment_data = load_experiment_conf(sourcing_parameters_path)
total_time = 100
torch.set_default_tensor_type('torch.cuda.FloatTensor')

# %%
sourcing_parameters = dict(ce=int(experiment_data.c_e),
                           cr=int(experiment_data.c_r),
                           le=int(experiment_data.l_e),
                           lr=int(experiment_data.l_r),
                           h=int(experiment_data.h),
                           b=int(experiment_data.b),
                           T=total_time,
                           fe = int(experiment_data.f_e),
                           fr = int(experiment_data.f_r)

                          )

# %%
sourcing_parameters
# Out:
# {'ce': 5,
#  'cr': 0,
#  'le': 0,
#  'lr': 2,
#  'h': 15,
#  'b': 85,
#  'T': 100,
#  'fe': 100,
#  'fr': 50}

# %% [markdown]
# ## NNC Initialization
# Here we initialize an NNC model and set  its hyperparameters for training.

# %%
### One can experiment with different layer architectures and activations per layer
nnc_hyperparameters = dict(
    n_hidden_units = [64, 32, 16, 8]
)

### We use celu non-linearities for the input layer, hidden layers, and output layer
nnc_hyperparameters['n_activations'] = [torch.nn.CELU(alpha=1)]*(2 + len(nnc_hyperparameters['n_hidden_units']))


fcc = LSTMController(lr=sourcing_parameters['lr'], 
                                         le=sourcing_parameters['le'], 
                                          hidden_size=32,
                                          num_layers=1,
                                        ) # controller neural network object

# %% [markdown]
# ## Dynamics Initialization
# To further optimize NNC (''fine tuning''), we now apply gradient propagation to the inventory evolution equation:
#
# $I_t = I_{t-1} + q^{\rm e}_{t-l_{\rm e}} + q^{\rm r}_{t-l_{\rm r}} - D_t$
#
# where $I_0, q^{\rm e}_{t},q^{\rm r}_{t}$ are NNC outputs.

# %%
dsd = SequentialDualSourcing(fcc, I_0=6, **sourcing_parameters) # Dual Sourcing Dynamics object

# %% [markdown]
# We preserve the best performing model in training, assuming that the neural network generalizes well during training and that our training sample is large enough.

# %%
best_loss = [np.infty]
best_model = [None]

# %%
all_training_costs = []

# %% [markdown]
# We observe that we have a neural network that outputs $q^{\rm r}_{t-l_{\rm r}}, q^{\rm e}_{t-l_{\rm e}}$ given the input described above.
# The initial inventory $I_0$ is independent of inputs and can be learned separately (in a way that is similar to learning a bias term of a neural network).
# We use separate optimizers to learn order quantities and initial inventory.
# This may create learning variance, as one optimizer may overfit on a value that is directly changed by another optimizer.
# To reduce the learning variance, we let the order optimizer operate on 7 out of 10 learning epochs and the inventory optimizer on the remaining epochs.

# %%
optimizer = torch.optim.RMSprop(#[dsd.I_0],
                                list(fcc.parameters()), 
                                lr=3*1e-3
                               )
optimizer2 = torch.optim.RMSprop([dsd.I_0],
                                #list(fcc.parameters()), 
                                lr=1e-3
                               )

# %% [markdown]
# We now fine tune the model after imitation, in order to generalize and hopefully outperform the method used to train the model.
# To do so, we repetively train and fine tune the parameters of 128 trajectories generated by setting a specific random seed. We do not resample new trajectories, as we want the network to overfit on the process. Sampling new samples could increase the input variance, and could potentially slow/prohibit convergence.

# %%
fine_tuning_iterations = 3000
minibatch_size = 256
random_seed = 4

t0 = time.time()
for it in range(fine_tuning_iterations):
    optimizer.zero_grad()
    optimizer2.zero_grad()
    def closure():
        dsd.reset(minibatch_size, seed=random_seed+1)
        nn_context = {}
        total_costs = 0
        for i in range(dsd.T):
            current_costs, demands, current_inventories, qr, qra, qe, qea, nn_context = dsd.simulate(nn_context)
            total_costs = current_costs.mean() + total_costs
        all_training_costs.append(float(total_costs)/dsd.T)
        total_costs.backward()
        if it % 20 == 0:
            print(total_costs/dsd.T)
        if total_costs < best_loss[0]:
            best_loss[0] = total_costs.detach().cpu().item()
            best_model[0] = deepcopy(fcc.state_dict())
        return total_costs
    #if it > 1 and all_training_costs[-1] <= 26.4:
    #        break
    if it % 10 > 6:
        optimizer2.step(closure)
    else:
        optimizer.step(closure)
t1 = time.time()
total = t1-t0
print(total)
# Out:
# tensor(131.2363, grad_fn=<DivBackward0>)
# tensor(115.3961, grad_fn=<DivBackward0>)
# tensor(119.7557, grad_fn=<DivBackward0>)
# tensor(117.8203, grad_fn=<DivBackward0>)
# tensor(116.1863, grad_fn=<DivBackward0>)
# tensor(116.0973, grad_fn=<DivBackward0>)
# tensor(115.4174, grad_fn=<DivBackward0>)
# tensor(114.9541, grad_fn=<DivBackward0>)
# tensor(114.5838, grad_fn=<DivBackward0>)
# tensor(114.6479, grad_fn=<DivBackward0>)
# tensor(114.6984, grad_fn=<DivBackward0>)
# tensor(113.6910, grad_fn=<DivBackward0>)
# tensor(113.4301, grad_fn=<DivBackward0>)
# tensor(113.6254, grad_fn=<DivBackward0>)
# tensor(113.1795, grad_fn=<DivBackward0>)
# tensor(113.1490, grad_fn=<DivBackward0>)
# tensor(111.7639, grad_fn=<DivBackward0>)
# tensor(112.7152, grad_fn=<DivBackward0>)
# tensor(111.7615, grad_fn=<DivBackward0>)
# tensor(112.1465, grad_fn=<DivBackward0>)
# tensor(111.9695, grad_fn=<DivBackward0>)
# tensor(111.4061, grad_fn=<DivBackward0>)
# tensor(111.8191, grad_fn=<DivBackward0>)
# tensor(111.7758, grad_fn=<DivBackward0>)
# tensor(111.7807, grad_fn=<DivBackward0>)
# tensor(111.5398, grad_fn=<DivBackward0>)
# tensor(111.1322, grad_fn=<DivBackward0>)
# tensor(111.3982, grad_fn=<DivBackward0>)
# tensor(111.3980, grad_fn=<DivBackward0>)
# tensor(111.3818, grad_fn=<DivBackward0>)
# tensor(110.6410, grad_fn=<DivBackward0>)
# tensor(111.2475, grad_fn=<DivBackward0>)
# tensor(111.4437, grad_fn=<DivBackward0>)
# tensor(110.9967, grad_fn=<DivBackward0>)
# tensor(110.1443, grad_fn=<DivBackward0>)
# tensor(110.5100, grad_fn=<DivBackward0>)
# tensor(110.8961, grad_fn=<DivBackward0>)
# tensor(110.2299, grad_fn=<DivBackward0>)
# tensor(111.2475, grad_fn=<DivBackward0>)
# tensor(110.8787, grad_fn=<DivBackward0>)
# tensor(110.0275, grad_fn=<DivBackward0>)
# tensor(110.0754, grad_fn=<DivBackward0>)
# tensor(109.9273, grad_fn=<DivBackward0>)
# tensor(110.0547, grad_fn=<DivBackward0>)
# tensor(110.0684, grad_fn=<DivBackward0>)
# tensor(109.1531, grad_fn=<DivBackward0>)
# tensor(109.9158, grad_fn=<DivBackward0>)
# tensor(109.5314, grad_fn=<DivBackward0>)
# tensor(107.8551, grad_fn=<DivBackward0>)
# tensor(105.5187, grad_fn=<DivBackward0>)
# tensor(107.1477, grad_fn=<DivBackward0>)
# tensor(108.0145, grad_fn=<DivBackward0>)
# tensor(106.8213, grad_fn=<DivBackward0>)
# tensor(105.9330, grad_fn=<DivBackward0>)
# tensor(104.6141, grad_fn=<DivBackward0>)
# tensor(108.9746, grad_fn=<DivBackward0>)
# tensor(105.2822, grad_fn=<DivBackward0>)
# tensor(104.1355, grad_fn=<DivBackward0>)
# tensor(107.2518, grad_fn=<DivBackward0>)
# tensor(105.8613, grad_fn=<DivBackward0>)
# tensor(105.9810, grad_fn=<DivBackward0>)
# tensor(103.9810, grad_fn=<DivBackward0>)
# tensor(104.7492, grad_fn=<DivBackward0>)
# tensor(108.6232, grad_fn=<DivBackward0>)
# tensor(104.3432, grad_fn=<DivBackward0>)
# tensor(102.9275, grad_fn=<DivBackward0>)
# tensor(103.0912, grad_fn=<DivBackward0>)
# tensor(104.6375, grad_fn=<DivBackward0>)
# tensor(102.1186, grad_fn=<DivBackward0>)
# tensor(104.4121, grad_fn=<DivBackward0>)
# tensor(101.8766, grad_fn=<DivBackward0>)
# tensor(105.5658, grad_fn=<DivBackward0>)
# tensor(101.8063, grad_fn=<DivBackward0>)
# tensor(105.6518, grad_fn=<DivBackward0>)
# tensor(104.3822, grad_fn=<DivBackward0>)
# tensor(100.2949, grad_fn=<DivBackward0>)
# tensor(102.6406, grad_fn=<DivBackward0>)
# tensor(102.8352, grad_fn=<DivBackward0>)
# tensor(101.4734, grad_fn=<DivBackward0>)
# tensor(101.2117, grad_fn=<DivBackward0>)
# tensor(103.9990, grad_fn=<DivBackward0>)
# tensor(100.1178, grad_fn=<DivBackward0>)
# tensor(101.8912, grad_fn=<DivBackward0>)
# tensor(100.3912, grad_fn=<DivBackward0>)
# tensor(98.3670, grad_fn=<DivBackward0>)
# tensor(102.5057, grad_fn=<DivBackward0>)
# tensor(101.5670, grad_fn=<DivBackward0>)
# tensor(99.5879, grad_fn=<DivBackward0>)
# tensor(98.4740, grad_fn=<DivBackward0>)
# tensor(99.2543, grad_fn=<DivBackward0>)
# tensor(101.2637, grad_fn=<DivBackward0>)
# tensor(98.2309, grad_fn=<DivBackward0>)
# tensor(101.1420, grad_fn=<DivBackward0>)
# tensor(98.7230, grad_fn=<DivBackward0>)
# tensor(96.3613, grad_fn=<DivBackward0>)
# tensor(100.2246, grad_fn=<DivBackward0>)
# tensor(96.9684, grad_fn=<DivBackward0>)
# tensor(98.6984, grad_fn=<DivBackward0>)
# tensor(98.6287, grad_fn=<DivBackward0>)
# tensor(98.8816, grad_fn=<DivBackward0>)
# tensor(98.0572, grad_fn=<DivBackward0>)
# tensor(98.9578, grad_fn=<DivBackward0>)
# tensor(99.6992, grad_fn=<DivBackward0>)
# tensor(99.7908, grad_fn=<DivBackward0>)
# tensor(94.0271, grad_fn=<DivBackward0>)
# tensor(95.4402, grad_fn=<DivBackward0>)
# tensor(96.6352, grad_fn=<DivBackward0>)
# tensor(95.7672, grad_fn=<DivBackward0>)
# tensor(94.5488, grad_fn=<DivBackward0>)
# tensor(94.2570, grad_fn=<DivBackward0>)
# tensor(94.2668, grad_fn=<DivBackward0>)
# tensor(93.2186, grad_fn=<DivBackward0>)
# tensor(97.7398, grad_fn=<DivBackward0>)
# tensor(92.5059, grad_fn=<DivBackward0>)
# tensor(94.5221, grad_fn=<DivBackward0>)
# tensor(93.1406, grad_fn=<DivBackward0>)
# tensor(95.1809, grad_fn=<DivBackward0>)
# tensor(94.3338, grad_fn=<DivBackward0>)
# tensor(93.3307, grad_fn=<DivBackward0>)
# tensor(92.4475, grad_fn=<DivBackward0>)
# tensor(92.9855, grad_fn=<DivBackward0>)
# tensor(93.4004, grad_fn=<DivBackward0>)
# tensor(93.4891, grad_fn=<DivBackward0>)
# tensor(92.0978, grad_fn=<DivBackward0>)
# tensor(90.5061, grad_fn=<DivBackward0>)
# tensor(88.8297, grad_fn=<DivBackward0>)
# tensor(93.1342, grad_fn=<DivBackward0>)
# tensor(93.5102, grad_fn=<DivBackward0>)
# tensor(89.2939, grad_fn=<DivBackward0>)
# tensor(88.2537, grad_fn=<DivBackward0>)
# tensor(90.8031, grad_fn=<DivBackward0>)
# tensor(87.2123, grad_fn=<DivBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-dbc3654f3cb1> in <module>
#      27         optimizer2.step(closure)
#      28     else:
# ---> 29         optimizer.step(closure)
#      30 t1 = time.time()
#      31 total = t1-t0
#
# ~/miniconda3/envs/numdyn/lib/python3.8/site-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#      86                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#      87                 with torch.autograd.profiler.record_function(profile_name):
# ---> 88                     return func(*args, **kwargs)
#      89             return wrapper
#      90
#
# ~/miniconda3/envs/numdyn/lib/python3.8/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      26         def decorate_context(*args, **kwargs):
#      27             with self.__class__():
# ---> 28                 return func(*args, **kwargs)
#      29         return cast(F, decorate_context)
#      30
#
# ~/miniconda3/envs/numdyn/lib/python3.8/site-packages/torch/optim/rmsprop.py in step(self, closure)
#      94         if closure is not None:
#      95             with torch.enable_grad():
# ---> 96                 loss = closure()
#      97
#      98         for group in self.param_groups:
#
# <ipython-input-12-dbc3654f3cb1> in closure()
#      15             total_costs = current_costs.mean() + total_costs
#      16         all_training_costs.append(float(total_costs)/dsd.T)
# ---> 17         total_costs.backward()
#      18         if it % 20 == 0:
#      19             print(total_costs/dsd.T)
#
# ~/miniconda3/envs/numdyn/lib/python3.8/site-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     305                 create_graph=create_graph,
#     306                 inputs=inputs)
# --> 307         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     308
#     309     def register_hook(self, hook):
#
# ~/miniconda3/envs/numdyn/lib/python3.8/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     152         retain_graph = create_graph
#     153
# --> 154     Variable._execution_engine.run_backward(
#     155         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     156         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#
# KeyboardInterrupt:

# %%
best_loss[0]/dsd.T
# Out:
# 87.2123046875

# %%
sourcing_parameters

# %% [markdown]
# train one nn for lr=2,3,4
#
# Takes several thousand epochs to train one initial NN nicely, then finetuning brings it 1-5% closer to DP
# Fewer epochs for fine-tuning
#
#
# transfer learn for new parameters except lr

# %% [markdown]
# lower lr and increase learning rate close to dp and then increase again.
#
# Start from 10^-3 learning rate
# minibatch size: 256 - 1024 work relative well.
# for lr > 2 use T=150, 200, longer lrs need bigger lrs
#
# Nice initial inventory level, too small and too large initial inventories may bias trainning.
# Between 4 and 8 seems to work very well.

# %%
fine_tuning_iterations = 3000
minibatch_size = 256
random_seed = 500

t0 = time.time()
dsd.reset(minibatch_size, seed=random_seed+1)
nn_context = {}
total_costs = 0
for i in range(dsd.T):
    current_costs, demands, current_inventories, qr, qra, qe, qea, nn_context = dsd.simulate(nn_context)
    total_costs = current_costs.mean() + total_costs

print(total_costs/dsd.T)

t1 = time.time()
total = t1-t0
print(total)
# Out:
# tensor(121.0072, grad_fn=<DivBackward0>)
# 0.2254953384399414
